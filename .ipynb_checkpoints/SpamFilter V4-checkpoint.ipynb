# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from tqdm import tqdm_notebook as tqdm
import regex as re
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import nltk
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.feature_extraction import DictVectorizer
import itertools
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
import pdb
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from nltk import bigrams

# %%
def cleanup(data_df):
    
    # remove nans
    data_df['has_media'].fillna(0, inplace=True)
    
    # remove urls
    data_df['regtext'] = data_df['text'].apply(lambda t: re.sub(r"http.?://[^\s]+[\s]?", '', t))
    
    # remove numbers
    data_df['regtext'] = data_df['regtext'].apply(lambda t: re.sub(r"\s?[0-9]+\.?[0-9]*", '', t))
    
    # remove special characters
    data_df['regtext'] = data_df['regtext'].apply(lambda t: re.sub(r"[^a-zA-Z0-9]+", ' ', t))
    
    # make lowercase
    data_df['regtext'] = data_df['regtext'].str.lower()
    
    # add user_id to text
    data_df['text'] = data_df.apply(lambda row : row['text'] + ' ' + row['usernameTweet'], axis=1)

# %%
def tokenStem(data_df):
    
    stemmer = nltk.PorterStemmer()
    tokenizer = nltk.word_tokenize
    stop_words = set(stopwords.words('english'))

    
    #tokenize
    data_df['regtext'] = data_df['regtext'].apply(lambda t: tokenizer(t))
    
    #stem
    data_df['regtext'] = data_df['regtext'].apply(lambda t: [stemmer.stem(word) for word in t if word not in stop_words])

# %%
def genExtrafeatures(data_df):    
    
    def count_occurences(character, word_array):
        counter = 0
        for j, word in enumerate(word_array):
            for char in word:
                if char == character:
                    counter += 1
        return counter
    
    # split text
    data_df['split'] = data_df['text'].apply(lambda t: t.split(" "))
    
    # number of $
    data_df['nbr_dol'] = data_df['split'].apply(lambda t: count_occurences('$', t))
    
    # number of :
    data_df['nbr_col'] = data_df['split'].apply(lambda t: count_occurences(':', t))
    
    # number of -
    data_df['nbr_hy'] = data_df['split'].apply(lambda t: count_occurences('-', t))
    
    # number of %
    data_df['nbr_per'] = data_df['split'].apply(lambda t: count_occurences('%', t))
    
    # number of characters
    data_df['nbr_chars'] = data_df['text'].apply(lambda t: len(t))
    
    # number of words in tweet
    data_df['nbr_words'] = data_df['split'].apply(lambda t: len(t))
    
    # number of tokens
    data_df['nbr_tokens'] = data_df['regtext'].apply(lambda t: len(t))
    
    # tok - words
    data_df['wordlesstok'] = data_df['nbr_words'] - data_df['nbr_tokens']
    
    # number of hashtags
    data_df['nbr_tags'] = data_df['split'].apply(lambda t: count_occurences('#', t))
    
    # number of !
    data_df['nbr_ex'] = data_df['split'].apply(lambda t: count_occurences('!', t))
    
    # number of ?
    data_df['nbr_q'] = data_df['split'].apply(lambda t: count_occurences('', t))
    
    # number of mentions
    data_df['nbr_mentions'] = data_df['split'].apply(lambda t: count_occurences('@', t))
    
    # number of urls
    data_df['has_url'] = data_df['text'].str.contains('http')

# %%
## Load Data

path = 'Data/Cleaned/xrp_cleaned_date.pkl'
randata_df = pd.read_pickle(path)

path = 'Data/Raw/goodUserCrypto.pkl'
gooddata_df = pd.read_pickle(path)

cleanup(gooddata_df)
cleanup(randata_df)
tokenStem(gooddata_df)
tokenStem(randata_df)
genExtrafeatures(gooddata_df)
genExtrafeatures(randata_df)

# %%
## Create Spam List

spamWords = ['ico', 'freetoken', 'token', 'airdrop', 'airdrops', 'rippleprice_', 'bigpumpgroup', 'bounty', 'usd', 'korea price', 'binance', 'current price', \
            'cryptopricexrp', 'cryptobot', 'coinstats', 'coinpricenow', 'cryptogulp', 'ripplebot1h', 'bigdata', 'RippleMarket','CryptoGulp', 'ripplebot_cs', \
            'cryptopricebot','VirtualMoneyBot','coinstats','JustFactsNL', 'free', 'trx', 'XrpTicker', 'aWebAnalysis', 'scotlarock727', '1bitcoinkaclira', \
            'pureinvestments']
spamWordsCon = ("|").join(spamWords)

## Label Spam
randata_df['Spam'] = randata_df['text'].str.contains(spamWordsCon)
gooddata_df['Spam'] = False

# %%
randata_df['Spam'].sum()
# Out:
# 12014

# %%
## Make training list

training_df = gooddata_df
training_df = training_df.append(randata_df[randata_df['Spam'] == True])

# %%
training_df.head()
# Out:
#              ID   Spam            datetime  has_media  has_url  is_reply  \
# 0  8.794407e+17  False 2017-06-26 16:46:13        0.0    False       1.0
# 1  9.830839e+17  False 2018-04-08 16:47:12        0.0    False       1.0
# 2  9.895482e+17  False 2018-04-26 12:54:16        1.0     True       0.0
# 3  9.626423e+17  False 2018-02-11 05:59:37        0.0     True       0.0
# 4  9.915655e+17  False 2018-05-02 02:30:13        0.0    False       0.0
#
#    is_retweet                     medias  nbr_chars  nbr_col     ...       \
# 0         0.0                        NaN        147        0     ...
# 1         0.0                        NaN        215        0     ...
# 2         0.0  [https://t.co/ra4K4ln6yx]        194        1     ...
# 3         0.0                        NaN        345        2     ...
# 4         0.0                        NaN        230        0     ...
#
#    nbr_tokens  nbr_words                                            regtext  \
# 0          10         28  [lost, one, nick, think, term, creation, troub...
# 1          12         35  [freedom, speech, protect, infring, govern, in...
# 2          20         28  [fantast, video, archiv, coinscrum, minicon, w...
# 3          28         55  [everi, morn, read, post, elit, trader, list, ...
# 4          19         39  [ask, idl, suffer, eat, sand, crow, vultur, ho...
#
#    rounded_dateTime                                              split  \
# 0               NaT  [Lost, me, on, that, one,, Nick, , \nThink, it...
# 1               NaT  [Not, only, that,, but, freedom, of, speech, i...
# 2               NaT  [A, Fantastic, Video, , From, , The, Archives,...
# 3               NaT  [Every, morning, I, read, through, the, posts,...
# 4               NaT  ["Ask, them, why, they, idle, there\nWhile, we...
#
#                                                 text  \
# 0  Lost me on that one, Nick  \nThink it's the te...
# 1  Not only that, but freedom of speech is only p...
# 2  A Fantastic Video  From  The Archives - Coinsc...
# 3  Every morning I read through the posts  from  ...
# 4  "Ask them why they idle there\nWhile we suffer...
#
#                                          url             user_id  \
# 0     /PJSanderson/status/879440684624871424           168649848
# 1    /SeamusWalsh2/status/983083861763473408           343861762
# 2       /coinscrum/status/989548224171167744          1196956998
# 3  /whatbitcoindid/status/962642274596335616  893818632089763840
# 4    /poetrypotion/status/991565507051577344            62152913
#
#     usernameTweet  wordlesstok
# 0     PJSanderson           18
# 1    SeamusWalsh2           23
# 2       coinscrum            8
# 3  whatbitcoindid           27
# 4    poetrypotion           20
#
# [5 rows x 30 columns]

# %%
def reg2dict(row):
    out = {}
    
    for w in row['regtext']:
        out[w] = 1
        
    for b in bigrams(row['regtext']):
        out[b[0]+b[1]] = 1
        
    out['has_media'] = row['has_media']
    out['has_url'] = row['has_url']
    out['is_reply'] = row['is_reply']
    out['wordlesstok'] = row['wordlesstok']
    out['is_retweet'] = row['is_retweet']
    out['nbr_chars'] = row['nbr_chars']
    out['nbr_ex'] = row['nbr_ex']
    out['nbr_favorite'] = row['nbr_favorite']
    out['nbr_mentions'] = row['nbr_mentions']
    out['nbr_q'] = row['nbr_q']
    out['nbr_reply'] = row['nbr_reply']
    out['nbr_retweet'] = row['nbr_retweet']
    out['nbr_tags'] = row['nbr_tags']
    out['nbr_tokens'] = row['nbr_tokens']
    out['nbr_words'] = row['nbr_words']    
    out['nbr_dol'] = row['nbr_dol']
    out['nbr_per'] = row['nbr_per']
    out['nbr_hy'] = row['nbr_hy']
    out['nbr_col'] = row['nbr_col']
    
    return out

# %%
X_data = []

for index, row in training_df.iterrows():
    X_data.append(reg2dict(row))

# %%
## dictVectorize

vec = DictVectorizer()

X_data_v = vec.fit_transform(X_data).toarray()

# %%
Y_data = training_df['Spam'].tolist()

# %% [markdown]
# fig = plt.figure()
#
# labels = ['Spam', 'Not Spam']
# i = 0
# for v in [True, False]:
#     subset = plot_df[plot_df['Pred'] == v]
#     sns.distplot(subset['Pval'], label = str(v))
#     i += 1
#
# plt.legend()
# fig.savefig('ExpandedFeatureSpamClassifier')

# %%
RFC = RandomForestClassifier(max_depth=7)
RFC.fit(X_data_v, Y_data)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=7, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
## Load Data

path = 'Data/Cleaned/processed_data.pkl'
tweets_df = pd.read_pickle(path)

cleanup(tweets_df)
tokenStem(tweets_df)
genExtrafeatures(tweets_df)

X_tweets = []

for index, row in tweets_df.iterrows():
    X_tweets.append(reg2dict(row))
    
X_tweets_v = vec.transform(X_tweets)

# %%
Y_pred = RFC.predict(X_tweets_v)
Pval = RFC.predict_proba(X_tweets_v)[:,0]

# %%
sum(Y_pred)
# Out:
# 21994

# %%
tweets_df['Ypred'] = Y_pred
tweets_df['trustworthiness'] = Pval.tolist()

# %%
tweets_df.head()
# Out:
#              ID            datetime  is_reply  is_retweet  nbr_favorite  \
# 0  9.885302e+17 2018-04-23 17:29:08       0.0         0.0           0.0
# 1  9.866292e+17 2018-04-18 11:35:08       0.0         0.0           0.0
# 2  9.847927e+17 2018-04-13 09:57:41       0.0         0.0           0.0
# 3  9.863800e+17 2018-04-17 19:05:02       0.0         0.0           0.0
# 4  9.866047e+17 2018-04-18 09:57:42       0.0         0.0           0.0
#
#    nbr_reply  nbr_retweet                                               text  \
# 0        0.0          0.0  New post (Could  Ripple   XRP  Really Reach $1...
# 1        0.0          0.0  Long/Short Bitcoin swings with up to 100x Leve...
# 2        0.0          0.0  Did you know that you can buy, sell, store, co...
# 3        0.0          0.0  1  Ripple  = 0.6589 USD.  Ripple  has changed ...
# 4        0.0          0.0  How Is #Ripple  Different From All Other #Cryp...
#
#                                           url             user_id  \
# 0  /ExcelVisibility/status/988530235493748736           815322320
# 1     /KerriHermanx/status/986629205856223233  956303409065414656
# 2    /coindirectcom/status/984792745666580481  915453520924545025
# 3     /RippleMarket/status/986380040517701633  848989770923601922
# 4       /Matthix191/status/986604686856933376  916641996823031808
#
#         ...       nbr_tokens  wordlesstok nbr_tags nbr_ex  nbr_q nbr_mentions  \
# 0       ...               17           10        0      0      0            0
# 1       ...               38           57        0      1      0            0
# 2       ...               26           27        2      0      0            1
# 3       ...               14           17        3      0      0            0
# 4       ...               35           56        8      0      0            0
#
#    has_url  Ypred                                       Pval trustworthiness
# 0     True  False  [0.6020102314139734, 0.39798976858602664]        0.602010
# 1     True   True  [0.34808927633992565, 0.6519107236600743]        0.348089
# 2     True  False  [0.5454488204348749, 0.45455117956512503]        0.545449
# 3     True   True   [0.4734575025858341, 0.5265424974141659]        0.473458
# 4     True   True  [0.10883837028616447, 0.8911616297138355]        0.108838
#
# [5 rows x 36 columns]

# %%
tweets_df.to_pickle('Data/Cleaned/Filtered_tweets_df.pkl')

# %%
## View spam some tweets

for i in range(1000):
    if Y_pred[i] == True:
        print(tweets_df['regtext'][i])
        print('')
        print('')
# Out:
# New post (Could  Ripple   XRP  Really Reach $10.00 In 39 Days?) has been published on  -  https:// masscryptocurrency.com/?p=2664   pic.twitter.com/6Dlog2TNQE ExcelVisibility
#
#
# Did you know that you can buy, sell, store, convert and transfer @Ripple  #XRP  on  http:// Coindirect.com       in the UK, EU countries, Australia, Kenya, Nigeria and South Africa. You can use fiat currency or convert other coins and exchange them for #Ripple  . coindirectcom
#
#
# 1  Ripple  = 0.6589 USD.  Ripple  has changed by -0.0026 USD in 30 mins. Live price:  https:// is.gd/hI9OcA    #ripple  #xrp  #cryptocurrency RippleMarket
#
#
# How Is #Ripple  Different From All Other #Cryptocurrencies ? An Ultimate Guide  https://www. reddit.com/r/Ripple/comme nts/8d58hr/how_is_ripple_different_from_all_other/   …
# #ripple  #tron   $ trx   $ xrp   $ eth   $ btc   $ xmr   $ ltc  #litecoin   $ etc   $ eos   $ neo   $ xlm   $ ada  #cardano   $ nem   $ iota   $ lsk   $ icx  #cryptonews  #redbux Matthix191
#
#
# immense Paid group now free for week  https:// goo.gl/PwS8QF
#
#   $ CGE   $ HEAT   $ SLS  17.23   $ POP   $ POE   $ BYC   $ SNGLS   $ NEX   $ XRP   $ XEM   $ SAFEX   $ PLBT   $ CLAM   $ TKN   $ SC   $ WAVES   $ TKY   $ CLUB   $ NMR   $ NAV   $ NXS
#    5F4bFhK926z3Tsnh4tn3k6Fz HyhhDx1ubatwX52
#
#
# Walmart And Moneygram Partnership Could Pump  Ripple  ( XRP ) @EtherWorldNews https:// ethereumworldnews.com/walmart-and-mo neygram-partnership-could-pump-ripple-xrp/   … vandecrypto
#
#
# # Verge  & @Pornhub , no chargeback, controls all ad traffic, 32 sites w/28K monthly buyers, no credit card fees, @Playboy  can't compare. Pornhub is the GOOGLE ADWords of the adult industry. #xmr  #btc  #vergefam  #xrp  #trx  #bitcoin https:// youtu.be/eeQ7tQa4I5c   Botliamrh
#
#
# «10x club». Now we opened our doors for 100 people   https:// goo.gl/xLTMrN
#
#   $ NAV   $ SAFEX   $ XRP   $ POE   $ CLAM   $ HEAT  17.23   $ CGE   $ SLS   $ BYC   $ TKN   $ SC   $ CLUB   $ NEX   $ SNGLS   $ TKY   $ POP   $ NXS   $ WAVES   $ PLBT   $ XEM   $ NMR
#    kQSsDazZrFd8aEi2t2ay7SZB w26WcNEE9kRF80B
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 13  http:// dlvr.it/QPSCJh   pic.twitter.com/q8ljjIurAc cryptcurnews
#
#
# Cryptos as of 09.53am GMT+1:
#
# (Bitfinex)
#
# #Bitcoin  (BTCUSD) +3.74%
# #Ethereum  (ETHUSD) +6.96%
# #Litecoin  (LTCUSD) +5.70%
# #Monero  (XMRUSD) +3.29%
# #Ripple  ( XRP /USD) +4.20%
#
# #Cryptocurrencies IC_Markets
#
#
# Yo, Adrian!  Ripple  has reached $ 0.750  https:// coinranking.com/coin/ripple-xrp    #Ripple   $ XRP  #cryptocurrency pic.twitter.com/D0AA8Vrin4 coinranking
#
#
# Looking for honest and profitable trading calls, recommendations and advice, join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ XLM   $ XMR   $ ZEC   $ ADA   $ SYS   $ NEO   $ LUX   $ OMG   $ POWR   $ VTC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ VEN   $ ICX   $ ZCL   $ DRGN   $ WTC   $ IC   $ TRX   $ QTUM   $ LSK   $ ZRX  46102 ChrisJordanTwit
#
#
# How to do 10x on one month? Easy  Check  https:// goo.gl/memYv3
#
#   $ CLAM   $ TKN   $ HEAT   $ CGE  17.23   $ XRP   $ SAFEX   $ SNGLS   $ POE   $ CLUB   $ TKY   $ NMR   $ XEM   $ POP   $ NEX   $ WAVES   $ SC   $ SLS   $ PLBT   $ BYC   $ NAV   $ NXS
#    K4rYAHKT2F4ezEsE223b5E3f w26WcNEE9kRF80B
#
#
# Cryptocurrency declared Halal under Islamic law – Bitcoin [BTC] market opens to 1.6 billion Muslims
#  https:// ift.tt/2ELRayh
#  $ BTC  #ETH   $ ETH  #Ripple  #BTC  #Bitcoin  #Ethereum   $ xrp  #BitcoinCash  #Altcoins CryptoAmb
#
#
# How to do 10x on one month? Easy  Check  https:// bit.ly/2JODoia
#
#   $ FLO   $ sc   $ zec   $ POWR   $ DICE   $ CFI   $ DRT   $ NEO   $ TX   $ KCS   $ ltc   $ MOT   $ SBD   $ icx   $ XSH   $ HMQ   $ WABI   $ NXS   $ MAID   $ xrp   $ UFO
#   hDTE4QeNrAaarZffd7AtEbH9 baranovaolesya1
#
#
# colossal Amazing Prediction of Signal Check Signals History ->  https:// goo.gl/DpUYYa
#
#   $ SC   $ HEAT  17.23   $ BYC   $ POP   $ CLUB   $ SNGLS   $ TKN   $ NMR   $ XEM   $ PLBT   $ POE   $ CGE   $ XRP   $ SLS   $ NXS   $ NEX   $ SAFEX   $ WAVES   $ TKY   $ CLAM   $ NAV
#    dTZFrHdK5iQ7NRAFzFtkr5bH lpww0kjEyUWs05M
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ MED   $ OMG   $ POWR   $ VTC   $ SC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  49419 irisblacktweets
#
#
# Make money by capitalizing on BTC volatility
#
# →  http:// bitmex.com/register/m9MNxm
#
# 10% Fee Discount!
#
#  $ ARK   $ BCH   $ DASH   $ XRP   $ QTUM   $ ELF   $ HSR   $ ZRX   $ ZCL   $ XRB   $ USDT   $ VEN   $ LINK   $ WAVES   $ NEO   $ ADA   $ GXS   $ DOGE pic.twitter.com/mp6ugAd1Tc KerriHermanx
#
#
# Ripple  Invests $25 Million in  XRP  in Blockchain Capital’s $150 Million VC Fund  http://www. bing.com/news/apiclick. aspx?ref=FexRss&aid=&tid=6AAEF6A1CBCD4372B21B4C3D4518504E&url=https%3A%2F%2Ffinance.yahoo.com%2Fnews%2Fripple-invests-25-million-xrp-145233799.html&c=2015452729644309169&mkt=en-us&utm_source=dlvr.it&utm_medium=twitter   … pic.twitter.com/xD8hb0wYod startupcrunch
#
#
# This guy give immense signals for free.  $ PRL  did 260% in one day. check —>  https:// goo.gl/fQzfbp
#
#   $ CLUB   $ NXS   $ POP   $ SNGLS   $ HEAT   $ NMR   $ SAFEX   $ SLS   $ CLAM   $ XRP   $ XEM   $ BYC   $ NAV   $ POE   $ PLBT   $ NEX   $ TKY   $ SC  17.23   $ WAVES   $ TKN   $ CGE
#    h3dK3iZD9ds54GfG3rz2DnS7 w26WcNEE9kRF80B
#
#
# Ever buy high, then sell low, then fomo in and sell at a low? Then join us we can help
#
#   https:// t.me/ddoge   .
#
#   $ BTC   $ VTC   $ XRP   $ XLM   $ VEN   $ MCO   $ XVG   $ DASH   $ XMR   $ LMC   $ MONA   $ TRX   $ ETP   $ SYS   $ Brd   $ BNB   $ Xvg   $ GVT   $ gup   $ TENX   $ Xlm   $ WTC   $ SLR   $ BTCRED   $ XRL   $ DGB   $ AION   $ LTC   $ GAS pic.twitter.com/ghYNHWfrJN iLoveCryptoo
#
#
# When @CNBCFastMoney  says buy #bitcoincash , maybe not the right time to buy. Remember when they recommended #ripple  #XRP  anyone?  https:// twitter.com/CNBCFastMoney/ status/986359682494234624   … Nathik_IN
#
#
# Is  Ripple  ( XRP ) Becoming Unstoppable?  http:// dlvr.it/QQJK7h   MoneyFromHome99
#
#
# When your #Bitcoin  #Waifu  has developed a
# sixth sense for buying the dip & selling the top.
#
# 1 - 100x Leverage
#
#    http:// AirdropKitty.com /
#
# Register Now & go Long  or Short  on #BTC  + #Altcoins
#
# #Cryptocurrency  #Ethereum  #ETH  #Litecoin  #Ripple  #Dash  #Monero  #NEO pic.twitter.com/3XBGeiAYyC AirdropKitty
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  19960 jackfrazer8
#
#
# Soon #SelfSell  will moon. Are you ready for that?
# #NEO  #ACT  #XRP  #LTC  #BTC  #XVG https:// medium.com/@self_sell/air drop-program-to-celebrate-selfsell-mainnet-launch-644bab3cee49   … realjano
#
#
# conservative and reasonable price #xrp  #ripple  #cryptocurrencies  #bitcoin https:// twitter.com/bitbit_ojin/st atus/988400407998222337   … edz_fx
#
#
# This guy give mammoth signals for free.  $ PRL  did 260% in one day. check —>  https:// goo.gl/ZzWQdp
#
#   $ WAVES   $ NXS   $ CGE   $ SC   $ NAV   $ CLUB   $ SAFEX   $ SLS   $ XRP   $ TKY   $ CLAM   $ NMR   $ HEAT   $ POE   $ PLBT   $ XEM  17.23   $ SNGLS   $ BYC   $ TKN   $ NEX   $ POP
#    YHSRyrdza3Breyd6bDkEfza9 ZQIEk1dDPDKGyO3
#
#
# Follow Rainbow Currency (TWNKL), Bitcoin, Ethereum,  Ripple  and all of your favorite cryptocurrency from this great news site!
#
#  https:// cryptorank.online /
#
# #allthenicestuff  #safeZone  #RainbowCurrency  #TWNKL SafeZoneInc
#
#
# # TechTopics :  Ripple  ( XRP ) Partners With Hyperledger
#
# #fintech  #cryptocurrency  #dlt  #blockchain  #iot  #hyperledger  #businessblockchain https:// ethereumworldnews.com/ripple-xrp-par tners-with-hyperledger/   … cichuck
#
#
# ( Ripple  price ( XRP /USD) breaks above$0.70 amid larger crypto rally) -  http:// invezz.com/uploads/story/ 30347/thumbs/ripple_price_story_full.jpg   …  -
#
# The  Ripple  price ( XRP /USD) has broken above the $0.70 level amid a... - ...  pic.twitter.com/6B6rdE2VxJ tradebuddyonlin
#
#
# New post ( Ripple  Exec Says  XRP  is ‘Absolutely Not a Security’) has been published on  http:// BitlyFool.com    -  http:// bitlyfool.com/?p=9876   pic.twitter.com/NR88Iiqms2 bitlyfool
#
#
# Long/Short Bitcoin volatility with up to 100x Leverage at BitMEX!
#
# 10% Fee Discount below!
#
#    http:// bitmex.com/register/m9MNxm
#
#  $ LINK   $ WAX   $ VEN   $ XRP   $ EOS   $ XLM   $ MIOTA   $ SALT   $ MED   $ ENG   $ DASH   $ NAS   $ ZRX   $ FCT   $ PART   $ GXS   $ REP   $ BCN pic.twitter.com/J48O341cs2 Crypto_Alerts_
#
#
# Why  Ripple 's  XRP  Outperformed the Other Top Cryptos This Week  http:// bit.ly/2HCdZaz   Carlos1138
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  45503 jackfrazer8
#
#
# Phat #Crypto  Loot & Sick Gains Are Now Available
#
# 1 - 100x Leverage
#
#    http:// AirdropKitty.com /
#
# Register Now & go Long  or Short  on #BTC  + #Altcoins
#
# #Litecoin  #LTC  #Ripple  #Dash  #Monero  #EthereumClassic
# #Bitcoin  #Cryptocurrency  #Ethereum  #ETH  #Cardano  #NEO pic.twitter.com/xP2eCnSxZc AirdropKitty
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  40195 nikfrazertech
#
#
# astronomical Paid group now free for week  https:// goo.gl/rxwVWi
#
#   $ NEX   $ POP   $ SAFEX   $ CLAM   $ XEM   $ SNGLS   $ TKY   $ POE   $ XRP   $ CGE  17.23   $ CLUB   $ HEAT   $ PLBT   $ WAVES   $ SLS   $ TKN   $ NXS   $ BYC   $ NAV   $ NMR   $ SC
#    k4k4sFa9R8FytatzEEtA7tT9 lpww0kjEyUWs05M
#
#
# Huge profit...real people...built on honesty and integrity not like those other jokers
#
#   https:// t.me/ddoge   .
#
#   $ BTC   $ VTC   $ XRP   $ XLM   $ VEN   $ MCO   $ XVG   $ DASH   $ XMR   $ LMC   $ MONA   $ TRX   $ ETP   $ SYS   $ Brd   $ BNB   $ Xvg   $ GVT   $ gup   $ TENX   $ Xlm   $ WTC   $ SLR   $ BTCRED   $ XRL   $ DGB   $ AION   $ DOGE   $ BTG pic.twitter.com/6XRhYNqxQU iLoveCryptoo
#
#
# Ripple  price news: MASSIVE price boost for  XRP  | City & Business | Finance  https:// good-stockinvest.com/2018/04/20/rip ple-price-news-massive-price-boost-for-xrp-city-business-finance/   … goodstockinvest
#
#
# Why  Ripple ’s  XRP  Outperformed the Other Top Cryptos This Week  http:// scratchtec.com/why-ripples-xr p-outperformed-the-other-top-cryptos-this-week/   … pic.twitter.com/9StpdSKLyC ScratchTechInc
#
#
# Hello! We started our «10x project» an you can follow our titanic signals for free  https:// goo.gl/neB8pv
#
#  17.23   $ CLAM   $ PLBT   $ XRP   $ CLUB   $ POE   $ SC   $ TKN   $ SAFEX   $ SNGLS   $ WAVES   $ HEAT   $ BYC   $ NEX   $ NAV   $ NMR   $ SLS   $ POP   $ TKY   $ XEM   $ NXS   $ CGE
#    zAz7keaSf7TY369te2s6Z3az HyhhDx1ubatwX52
#
#
# Speculation that Amazon To Start Accepting  Ripple  ($ XRP ) in 2018  http:// bitme.site/posts/74089   scharellztgro
#
#
# Ripple  ( XRP ) Winning Streak Continues – Under Best Choices for Long Term -  https:// buff.ly/2HBFHnV   ScottScanlon
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  58453 jackfrazer8
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  27798 jasonclarktwit
#
#
# World’s 4th Largest Crypto Exchange Huobi Expands To London As ‘Entry Point’ To EU Market
#  https:// cointelegraph.com/news/worlds-4t h-largest-crypto-exchange-huobi-expands-to-london-as-entry-point-to-eu-market   …
#
# #crypto  #cryptosignals  #cryptotrade  #cryptotrend  #btc  #btcsignals  #btctrade  #eth  #ethtrade  #ethsignals  #ripple  #cryptoexchange  #huobi  #london  #eumarket cryprotrend24
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  37621 jackfrazer8
#
#
# substantial Amazing Prediction of Signal Check Signals History ->  https:// goo.gl/xmX3LT
#
#   $ TKY   $ PLBT   $ NMR   $ WAVES   $ NXS   $ CLAM   $ SC  17.23   $ POE   $ CGE   $ CLUB   $ XRP   $ XEM   $ POP   $ NEX   $ HEAT   $ NAV   $ SNGLS   $ SAFEX   $ SLS   $ BYC   $ TKN
#    4tA3AyhBih7T9fHyfNFTtTAi ZQIEk1dDPDKGyO3
#
#
# Huge profit...real people...built on honesty and integrity not like those other jokers
#
#   https:// t.me/ddoge   .
#
#   $ BTC   $ VTC   $ XRP   $ XLM   $ VEN   $ MCO   $ XVG   $ DASH   $ XMR   $ LMC   $ MONA   $ TRX   $ ETP   $ SYS   $ Brd   $ BNB   $ Xvg   $ GVT   $ gup   $ TENX   $ Xlm   $ WTC   $ SLR   $ BTCRED   $ XRL   $ DGB   $ NMR   $ LTC   $ NEO pic.twitter.com/bNVm3Vq2zj iLoveCryptoo
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 21  https:// wd52t.app.goo.gl/02a5qgCURDLcRx DG2   … CryptomonnaiesG
#
#
# PLEASE STOP #IRONFX  ABUSE!
#
#  http://www. forexpeacearmy.com/forex-reviews/ 7653/www.ironfx.com   …  … …
#
# #bitcoin  #ethereum  #eurusd  #invest  #blockchain  #broker  #ripple  #xrp  #beattheboilerrooms  #tscrime  #Bild  #FXPRO  #fx  #BTC  #Finance  #consob  #MIFID2  #NYT  #financialtimes  #litecoin  #LTC  #stopbrokerscam  #BBC  #CNN  #cnbc  #NYTimes truffeforex
#
#
# 39 Earn 50%-80% profit with our daily signals
#  https:// goo.gl/sf9o51
#  $ BTC   $ NPXS   $ AUC   $ EVE   $ MAN   $ TFD   $ TOMO   $ SHIP   $ TAU   $ BAX   $ BEE   $ AION   $ VEE   $ AURA   $ TRAC   $ FSN   $ TRX   $ EOS   $ ETH   $ XVG   $ STORM   $ ADA   $ BCC   $ XLM   $ ICX   $ NEO   $ IOTA   $ SEN   $ XDCE   $ XRP   $ XML   $ HPB   $ ARDR   $ SYS fornit4
#
#
# NAV Coin is dropping big news on Monday! Whitepaper for their ADapps platform Valence!  https:// theusacommerce.com/nav-coin-nav-t he-rising-bitcoin-threat-is-dropping-big-news-on-monday/   …  #nav  #NAVCoin   $ nav  #cryptocurrency  #cryptocurrencies  #btc  #bitcoin  #eth  #ethereum  #ltc  #litecoin  #xvg  #VergeCurrency  #xmr  #monero  #xrp  #ripple  #privacy  #smartcontracts elyssanlol
#
#
# I just published “Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis…”  https:// medium.com/p/bitcoin-ethe reum-bitcoin-cash-ripple-stellar-litecoin-cardano-neo-eos-price-analysis-fc8fb00868a1   … p2psf
#
#
# Looking for honest and profitable trading calls, recommendations and advice, join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ XLM   $ XMR   $ ZEC   $ ADA   $ SYS   $ NEO   $ LUX   $ OMG   $ POWR   $ VTC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ VEN   $ ICX   $ ZCL   $ DRGN   $ WTC   $ IC   $ TRX   $ QTUM   $ LSK   $ ZRX  65331 ChrisJordanTwit
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 23  https:// ift.tt/2vKzHXA   pic.twitter.com/EOFU4YUMzl Crypto_News_247
#
#
# 1  Ripple  = 0.6615 USD.  Ripple  has increased by 0.0009 USD in 30 mins. Live price:  https:// is.gd/hI9OcA    #ripple  #xrp  #cryptocurrency RippleMarket
#
#
# Looking for honest and profitable trading calls, recommendations and advice, join:
#
#  http:// t.me/CryptoHeatsign als   …
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ XLM   $ XMR   $ ZEC   $ ADA   $ SYS   $ NEO   $ LUX   $ OMG   $ POWR   $ VTC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ VEN   $ ICX   $ ZCL   $ DRGN   $ WTC   $ IC   $ TRX   $ QTUM   $ LSK   $ ZRX  49987 cryptomike77
#
#
# Our  $ SAFEX  signal enormous did 80% in hours.  check here —>  https:// goo.gl/Us1sPT
#
#   $ SNGLS   $ NMR   $ CLAM   $ POP   $ TKN   $ PLBT   $ HEAT   $ SAFEX   $ XEM   $ NEX   $ TKY  17.23   $ CLUB   $ CGE   $ BYC   $ POE   $ XRP   $ NXS   $ NAV   $ SLS   $ WAVES   $ SC
#    YKG27NEGBDZNKK4ZZNRZDykt ZQIEk1dDPDKGyO3
#
#
# Join grand channel, Now its free for 1 week!  https:// goo.gl/SYu95q
#
#   $ SLS   $ HEAT   $ POP   $ NEX   $ PLBT   $ BYC   $ SNGLS   $ NMR   $ XEM   $ POE   $ WAVES   $ NAV   $ CLAM   $ SAFEX   $ CGE   $ TKY   $ NXS   $ CLUB   $ SC  17.23   $ XRP   $ TKN
#    AsE8A3YF4sfkaBbtiihK8tQr lpww0kjEyUWs05M
#
#
# @ Mayor_01  Hi there
# Try your chance to get 100  XRP   Ripple
# check the link  http:// bit.ly/GiveawayE   ranulpcheet
#
#
# How to do 10x on one month? Easy  Check  https:// goo.gl/tm9mY2
#
#   $ WAVES   $ SLS   $ XEM   $ PLBT   $ POE   $ NAV   $ POP   $ NEX   $ CLUB   $ CLAM   $ TKN   $ XRP  17.23   $ SNGLS   $ NMR   $ CGE   $ SAFEX   $ HEAT   $ NXS   $ BYC   $ SC   $ TKY
#    bZQnZET97Zdn7AiG5b444S54 lpww0kjEyUWs05M
#
#
# We are #LIVE  as BTC Rises Booom!  https:// youtu.be/0A3OV3I3WaQ    #BREAKING  #Hyped  #Hypedoncrypto  #RespectTheTA  #Bitcoincash  #XMR
# #BTC  #LTC  #ETH  #XRP  #XLM  #NEO  #TRX  #Cryptocurrency  #BCH
# #Bitcoin  #XEM  #DASH  #BTG  #EOS  #BTG  #QTUM  #BCH  #Ripple
#  #XLM  #IOT  #KMD  #OMG  #BTS  #ADA  #WTC scotlarock727
#
#
# Top 10 cryptocurrencies by market cap in the last hour #cryptocurrency   #bitcoin  #ethereum  #ripple  #bitcoincash  #litecoin  #eos  #cardano  #stellar  #neo  #monero pic.twitter.com/9ectZHmexv cryptotrends_me
#
#
# 82  Hi guys! Look at my signal cannel!
#   http:// t.me/cryptosignaal
#  $ MAN   $ SC   $ POE   $ GUP   $ DNT   $ WAX   $ BTC   $ OCT   $ RCN   $ BNB   $ VTC   $ VIBE   $ ARDR   $ ZCL   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ NEO   $ LUX   $ MED   $ POWR   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ SC fornit4
#
#
# Check. #XRP  ‘Absolutely Not’ A Security Says  Ripple  Chief Market Strategist  https:// cointelegraph.com/news/xrp-absol utely-not-a-security-says-ripple-chief-market-strategist   …  via @Cointelegraph  #tech  #digital  #data  #business  #blockchain pic.twitter.com/5YiAIrCGUy kuriharan
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  76938 jasonclarktwit
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 19  https:// cointelegraph.com/news/bitcoin-e thereum-bitcoin-cash-ripple-stellar-litecoin-cardano-neo-eos-price-analysis-april-19   …  via @Cointelegraph TweetGoldCrypto
#
#
# RIPPLE   XRP  CRYPTO APOLLO LAUNCH! FREE COIN GIVEAWAY! REAL CRYPTO NEWS DA...  https:// youtu.be/RKXIJ-yFkCw    via @YouTube aqm0869
#
#
# What is Behind $10 Year End Prediction for  Ripple  ( XRP )?  https:// hadeplatform.com/articles/2018/ 04/17/what-is-behind-10-year-end-prediction-for-ripple-xrp   … E_HawkinsJr
#
#
# How to do 10x on one month? Easy  Check  https:// goo.gl/H7crMW
#
#   $ POP   $ HEAT   $ CLUB   $ CLAM   $ SC   $ NMR   $ SAFEX   $ SNGLS   $ PLBT  17.23   $ POE   $ NAV   $ SLS   $ TKY   $ XEM   $ WAVES   $ NEX   $ TKN   $ NXS   $ CGE   $ XRP   $ BYC
#    NRaDFNSdn7fRB9S4ZADbTdQd ZQIEk1dDPDKGyO3
#
#
# Ripple  ( XRP ) tearing through the markets -  https:// buff.ly/2JmZmYp   NoteworthyWifey
#
#
# I gave  $ NAV  enormous signal  and it did 80% in hours. check here —>  https:// goo.gl/3R2Afh
#
#   $ CGE   $ XEM   $ XRP   $ SNGLS   $ WAVES   $ SC   $ TKN   $ NAV   $ BYC   $ POP   $ CLAM   $ POE   $ TKY   $ CLUB   $ PLBT   $ NMR   $ HEAT   $ NEX  17.23   $ NXS   $ SAFEX   $ SLS
#    B8KhNySNG6A2eBrZf5NRysfb lpww0kjEyUWs05M
#
#
# Not Yet: Watch for ‘Fake News’ Driving XVG and  XRP  Price Surge  http:// mycryptodictionary.com/blog/not-yet-w atch-for-fake-news-driving-xvg-and-xrp-price-surge/?utm_source=dlvr.it&utm_medium=facebook   … oskaaay
#
#
# How to do 10x on one month? Easy  Check  https:// goo.gl/smq1zf
#
#  17.23   $ XEM   $ NXS   $ POP   $ NEX   $ TKN   $ XRP   $ POE   $ SNGLS   $ PLBT   $ CLAM   $ NAV   $ SLS   $ WAVES   $ HEAT   $ TKY   $ SC   $ BYC   $ NMR   $ CGE   $ CLUB   $ SAFEX
#    QbYAybfnzHn7D96tSieHQ8ia lpww0kjEyUWs05M
#
#
# Looking for honest and profitable trading calls, recommendations and advice, join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ XLM   $ XMR   $ ZEC   $ ADA   $ SYS   $ NEO   $ LUX   $ OMG   $ POWR   $ VTC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ VEN   $ ICX   $ ZCL   $ DRGN   $ WTC   $ IC   $ TRX   $ QTUM   $ LSK   $ ZRX  74826 ChrisJordanTwit
#
#
# Crypto Exchange Huobi Expands Beyond Asia and Looks to London  https://www. newsbtc.com/2018/04/18/huo bi-exchange-expands-beyond-asia-with-new-office-in-london/   …
# #ripple  #tron  #trx  #xrp  #eth  #btc  #xmr  #ltc  #litecoin  #etc  #eos  #neo  #xlm  #ada  #cardano  #nem  #iota  #lsk  #icx  #cryptonews  #redbux Matthix191
#
#
# want to buy the next 30x coin? sign up on  http:// gate.io    now!
#
#   https:// gate.io/ref/1085639
#
#   $ BTC   $ ZCL   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ SNT   $ ADA   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ VOX   $ XEM   $ LSK   $ DGB   $ DOGE   $ COVAL   $ XVG   $ GRS   $ AMP   $ strat   $ sc   $ XRB   $ NAV   28248 pic.twitter.com/C4SKBlStbU michealbrowntw1
#
#
# Register with BitMEX for up to 100x Leverage!
#
# BitMEX allows you to go long/short on your trades!
#
#    http:// bitmex.com/register/m9MNxm
#
#  $ PAY   $ KMD   $ XRP   $ MED   $ POWR   $ PART   $ DOGE   $ BTM   $ GXS   $ REQ   $ DGD   $ BNB   $ AION   $ BNT   $ XP   $ BTC   $ XRB   $ NEBL   $ BCN pic.twitter.com/ljLj2OckXk DianneNeal0
#
#
# Former Regulator Calls Ethereum and  Ripple  “Non-Compliant Securities”  https:// hacked.com/former-regulat or-calls-ethereum-and-ripple-non-compliant-securities/   …  #ripple  #xrpthestandard   $ XRP myripplenews
#
#
# 4 Reasons that Show  Ripple  ( XRP ) is still Undervalued – Crypto Recorder  https:// good-stockinvest.com/2018/04/14/4-r easons-that-show-ripple-xrp-is-still-undervalued-crypto-recorder/   … pic.twitter.com/u0yKdSsVB7 goodstockinvest
#
#
# Join astronomical channel, Now its free for 1 week!  https:// goo.gl/hR9i52
#
#   $ WAVES   $ POP   $ SC  17.23   $ XEM   $ NMR   $ SLS   $ XRP   $ CLUB   $ NEX   $ TKY   $ NXS   $ POE   $ PLBT   $ CGE   $ NAV   $ SAFEX   $ SNGLS   $ HEAT   $ CLAM   $ TKN   $ BYC
#    8n35Qib4zsQiZK4H9fNAyReY ZQIEk1dDPDKGyO3
#
#
# # BTC  price decreased! Buying@$8840.98 & Selling@$8840.98   $ btc   $ eth   $ etc   $ neo   $ dgb   $ dash   $ strat   $ eos   $ omg   $ pay   $ xrp   $ xmr   $ gas   bitcoinhacks
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  52959 nikfrazertech
#
#
# «10x club». Now we opened our doors for 100 people   https:// goo.gl/sRptWW
#
#   $ BYC   $ CLAM   $ XRP   $ SC   $ CGE   $ TKN   $ SNGLS   $ XEM   $ PLBT   $ NEX   $ POP   $ TKY   $ NXS   $ SAFEX   $ HEAT   $ WAVES   $ NAV   $ POE  17.23   $ NMR   $ SLS   $ CLUB
#    kbAFiedFA6GiR6dtQan2e8Eh HyhhDx1ubatwX52
#
#
# # BTC  price increased! Buying@$8115.97 & Selling@$8115.97   $ btc   $ eth   $ etc   $ neo   $ dgb   $ dash   $ strat   $ eos   $ omg   $ pay   $ xrp   $ xmr   $ gas   bitcoinhacks
# Top12 from big coins: #EOS  2.03%, #XMR  1.28%, #ADA  1.14%, #XRP  0.73%, #NEO  0.63%, #BCH  0.33%, #LTC  0.3%, #DASH  0.28%, #XLM  0.28%, #BTC  0.09%, #ETH  -0.27%, #MIOTA  -0.27% pic.twitter.com/WAGabYvfRK CoinoMonitor
#
#
# The top 10 #cryptocurrencies  at a glance #btc  #xrp  #eth  #bch  #ada  #miota  #xlm  #neo  #ltc  #eos
#
# Watch and discuss live price updates
#  https:// coinpricetracker.com   pic.twitter.com/QjZZN3PxUS Coinpricetrack
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  42033 jackfrazer8
#
#
# Looking for honest and profitable trading calls, recommendations and advice, join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ XLM   $ XMR   $ ZEC   $ ADA   $ SYS   $ NEO   $ LUX   $ OMG   $ POWR   $ VTC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ VEN   $ ICX   $ ZCL   $ DRGN   $ WTC   $ IC   $ TRX   $ QTUM   $ LSK   $ ZRX  10325 cryptomike77
#
#
# Hello! We started our ball of firestar «10x project»  https:// bit.ly/2H2Mmqp
#
#   $ TX   $ icx   $ sc   $ zec   $ xrp   $ XSH   $ NXS   $ KCS   $ UFO   $ NEO   $ MAID   $ SBD   $ CFI   $ POWR   $ DRT   $ MOT   $ WABI   $ FLO   $ DICE   $ HMQ   $ ltc
#   y29A4Yt9s2QdzY8Q7D96d85H Jake3480
#
#
# @ Ultimatecrypto1  Hello
# We are giving out free 100  XRP   Ripple
# check the link  http:// bit.ly/GiveawayA1   ale6eolenev
#
#
# RT YahooFinance: Cryptocurrency exchange Kraken to shutter services in Japan  https:// yhoo.it/2qCMc2t    via coindesk #bitcoin   $ btc   $ xrp   $ eth  #blockchain  #crypto  #cryptocurrency ItsEricBass
#
#
# Transaction Type: PaymentChannelCreate
#  Amount: 1  XRP
# Sending Acct: rK6g2UYc4GpQH8DYdPG7wywyQbxkJpQTTN
# Receiving Acct: rMmjxZorrSii9d8suc2yecbBhRzZYwJAxp
# Paychan ID: 6041E8C2AFB5FD2F214BED9DB1B01D386CBF13D30F06A83C9CA3B0C6B216E449
# Link:  https:// xrpcharts.ripple.com/#/transactions /33967692691600E4B1A08708CDE2B5D07E2AF1BEE5DD15579F74B577F6142603   … XRPL_Monitor
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 18 - Rakesh Upadhyay  http:// bit.ly/2J8mB8A    #Altcoin
# News #Bitcoin  #Price  #Ethereum  #Price  #Bitcoin  #Cash  #Ripple  #Stellar  #Litecoin  #Cardano  #NEO  #EOS  #Price  #Analysis fiftyline50
#
#
# @ AALAziff  Hey
# Try your chance to get 100  Ripple   XRP
# check the Account   http:// bit.ly/GiveawayA   olganpgfstr
#
#
# 73  Hi guys! Look at my signal cannel!
#   http:// t.me/cryptosignaal
#  $ MAN   $ SC   $ POE   $ GUP   $ DNT   $ WAX   $ BTC   $ OCT   $ RCN   $ BNB   $ VTC   $ VIBE   $ ARDR   $ ZCL   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ NEO   $ LUX   $ MED   $ POWR   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ SC StepBeen
#
#
# Exclusive:  Ripple  Invests $25 Million in Blockchain Capital’s $150 Million Venture Fund  http://www. bing.com/news/apiclick. aspx?ref=FexRss&aid=&tid=64F435FADAA94A608B73682D3711944D&url=http%3A%2F%2Ffortune.com%2F2018%2F04%2F11%2Fripple-invests-blockchain-capital%2F&c=1609820914160243341&mkt=en-us&utm_source=dlvr.it&utm_medium=twitter   … pic.twitter.com/XinAknAJMY startupcrunch
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 23 #fintech https:// cointelegraph.com/news/bitcoin-e thereum-bitcoin-cash-ripple-stellar-litecoin-cardano-neo-eos-price-analysis-april-23   … etherfox
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 23:  https:// ift.tt/2vKzHXA   crypto_jane
#
#
# 1 sizable coin which will give you 500% check here —>  https:// goo.gl/181L68
#
#   $ NXS  17.23   $ SC   $ NEX   $ XRP   $ SLS   $ CLUB   $ NAV   $ POE   $ CLAM   $ NMR   $ WAVES   $ XEM   $ SAFEX   $ HEAT   $ POP   $ TKY   $ CGE   $ SNGLS   $ TKN   $ PLBT   $ BYC
#    zz8AHBNBENHHtNGdyRskDba8 lpww0kjEyUWs05M
#
#
# Payments company  Ripple   says it plans to invest in #startups  and #technology  companies to develop more uses for  XRP   https:// lnkd.in/fEwB-Ds   Krithika_Mi
#
#
# Huge profit...real people...built on honesty and integrity not like those other jokers
#
#   https:// t.me/ddoge   .
#
#   $ BTC   $ VTC   $ XRP   $ XLM   $ VEN   $ MCO   $ XVG   $ DASH   $ XMR   $ LMC   $ MONA   $ TRX   $ ETP   $ SYS   $ Brd   $ BNB   $ Xvg   $ GVT   $ gup   $ TENX   $ Xlm   $ WTC   $ SLR   $ BTCRED   $ XRL   $ DGB   $ AION   $ strat   $ BTG pic.twitter.com/ptAD2KSq6F iLoveCryptoo
#
#
# Bitcoin, Ether,  Ripple  and Litecoin Analysis - Prices Surge  https:// trib.al/FIH6yH1   coinstories
#
#
# 1  Ripple  = 0.6565 USD.  Ripple  has changed by -0.0018 USD in 30 mins. Live price:  https:// is.gd/hI9OcA    #ripple  #xrp  #cryptocurrency RippleMarket
#
#
# 38 days with Bots. Very profitable so far.
# If interested, check it out. Glad I did. Don't be left out.
#
# LTC Bot
#  https:// t.me/iCenter_Lite_B OT?start=1zyrbz29357   …
#
# ETH Bot
#  https:// t.me/iCenter_ETH_Bo t?start=top24t5997   …
#
# BTC Bot
#  https:// t.me/icenter_bot?st art=elsjcl65532   …
#
# #btc  #ltc  #eth  #ada  #trx  #xrp  #xvg  #neo  #omg  #xlm  #altcoins  #cryptocurrency City_Galloper
#
#
# # Bitcoin  price LIVE: BTC closing on $8k as expert claims 'the next bull phase' is close  http:// twib.in/l/aEABpjEgk8nb    via@@ antonia300873  #bitcoingold  #ripple antonia300873
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  21331 jackfrazer8
#
#
# Bitcoin [BTC], Ethereum [ETH],  Ripple  [ XRP ] and Bitcoin Cash [BCH] have set…  https:// goo.gl/fb/PVVbgD    #ripple  #xrp whats_a_bitcoin
#
#
# Crypto update: Bitcoin (BTC), Ethereum (ETH), and  Ripple  ( XRP ) storm higher again  $ ETH https:// ift.tt/2qyd9Va   CheapHotAlts
#
#
# Join gigantic channel, Now its free for 1 week!  https:// goo.gl/QcUFXc
#
#   $ SLS   $ BYC   $ PLBT   $ CLAM   $ SC   $ NXS   $ POE   $ WAVES   $ NAV   $ NEX   $ POP   $ XEM   $ XRP   $ TKY   $ HEAT   $ NMR   $ CGE  17.23   $ TKN   $ SNGLS   $ SAFEX   $ CLUB
#    tTa24ZDHyHf74kDFTiFd9SnT ZQIEk1dDPDKGyO3
#
#
# When the market is acting like this you know it's time to get Long & Strong
#
# 1 - 100x Leverage
#
#    http:// AirdropKitty.com /
#
# Register Now & go Long  or Short  on #BTC  + #Altcoins
#
# #Dash  #Monero  #Ripple  #Cardano  #NEO
# #Cryptocurrency  #Bitcoin  #Ethereum  #Litecoin pic.twitter.com/YGOUrA6CCH AirdropKitty
#
#
# Bitcoin's (BTC) Under-performance, Fueling The Altcoin Rally (ETH, LTC,  XRP , EOS)  http:// dlvr.it/QQTtlJ      HowToBuy NEO via →  http:// bit.do/_NEO   pic.twitter.com/ZG8aVjTPRP CryptoTraderPro
#
#
# Looking for honest and profitable trading calls, recommendations and advice, join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ XLM   $ XMR   $ ZEC   $ ADA   $ SYS   $ NEO   $ LUX   $ OMG   $ POWR   $ VTC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ VEN   $ ICX   $ ZCL   $ DRGN   $ WTC   $ IC   $ TRX   $ QTUM   $ LSK   $ ZRX  49179 cryptomike77
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 16  https:// ift.tt/2ERftuw   SebastianGogola
#
#
# 35 Billion, "a routine payment," went awry. And that's one bank making a routine payment. this is the Market #Ripple  is going after.
# #xrpthestandard
# #XRP   https:// twitter.com/FortuneMagazin e/status/987609411073073152   … fourthjohnxrp
#
#
# What is Chainlink and How it works ?
# #Ripple  #Bitcoin  #Litecoin  #Ethereum  #XRP  #Crypto  #Forex  #Altcoin  #Cryptocurrency  #Monero  #Cardano  #Litecoin  #Eos  #Stellar  #Neo  #Dash  #TRON
# #Tether  #ETH  #QTum  #OmiseGo  #Verge  #Lisk  #Zcash  #Steem  #Blockchain  #chainlink
#   https:// statrader.com/chainlink-revi ew-cryptocurrency/   … https:// twitter.com/StatraderCom/s tatus/985186285945020417   … devkumar92
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 21  http:// viralglobalnews.org/bitcoin-ethere um-bitcoin-cash-ripple-stellar-litecoin-cardano-neo-eos-price-analysis-april-21/   … ViralDailGlobal
#
#
# Why  Ripple ’s  XRP  Outperformed the Other Top Cryptos This Week  http:// concept71.com/why-ripples-xr p-outperformed-the-other-top-cryptos-this-week   … 0toMillionaire
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  37944 nikfrazertech
#
#
# Apple Using  Ripple  ( XRP ) Interledger As Banking Becomes Easier With  XRP  -  http:// cryptogeeks.com/apple-using-ri pple-xrp-interledger-banking-becomes-easier-xrp-0   … Cryptogeeks
#
#
# mammoth Amazing Prediction of Signal Check Signals History ->  https:// goo.gl/3496w3
#
#   $ CLUB   $ XRP   $ HEAT   $ CLAM   $ SC   $ TKY  17.23   $ CGE   $ NXS   $ SNGLS   $ POE   $ SAFEX   $ SLS   $ NMR   $ NEX   $ NAV   $ WAVES   $ PLBT   $ TKN   $ BYC   $ POP   $ XEM
#    9tKtKEFF3EbntrySQ29f74Az w26WcNEE9kRF80B
#
#
# 2 hour #RSI  Signals:
#
#  $ BTC  -  $ NCASH : 26.94
#  $ BTC  -  $ DTB : 29.37
#  $ BTC  -  $ EFL : 30.2
#  $ BTC  -  $ CLOAK : 31.06
#  $ BTC  -  $ THC : 35.61
#  $ BTC  -  $ TUSD : 37.21
#  $ BTC  -  $ GAM : 37.81
#  $ BTC  -  $ BNB : 39.87
#
#  $ XRP  #FLIXX  #AltCoins  #trading  #crowdsale  #BTC  #bitcoins   $ Alts  #masternodes   $ Crypto  #RMT  #litecoin CoinSignalBot
#
#
# # bitcoin  is back !!
#  binance
#  http:// binance.com/?ref=12067536
#
#  coinbase
#  http:// coinbase.com/join/5a273d8e7   …
#
#  kuncoin
#  http:// kucoin.com/#/?r=7b238x
# *
# #Crypto  #BTC  #ETH  #CryptoNews  #Cryptocurreny  #CryptoInvestor  #Dash  #Ripple  #BCH  #ETC  #LTC   #BTG  #EOS  #XMR  #IOT  #XRP   #Bittrex   #altcoin  #XVG pic.twitter.com/GZy6Kgs26W Yoshi69135022
#
#
# $ POE  increased very fast and will go to atm$, check this news ->  https:// goo.gl/T89w9h
#
#   $ SNGLS   $ XRP   $ POE   $ PLBT   $ SAFEX   $ HEAT   $ NAV   $ NXS   $ SLS   $ CLAM   $ TKY   $ TKN   $ POP   $ SC   $ XEM   $ NEX   $ CLUB   $ NMR   $ BYC   $ CGE   $ WAVES  17.23
#    AY4A8Q7rdBHb8Qn8r8d3N5hr ZQIEk1dDPDKGyO3
#
#
# Great Analysis crypto currency Channel!
#
# join =>  https:// t.me/Blackfoxtrading
#
#  $ BTC   $ XRP   $ LTC   $ ETH   $ ADA   $ XLM   $ XVG   $ TRX   $ OCN   $ IOST   $ NCASH   $ STORM   $ EOS   $ NEO   $ IOTA   $ CDT   $ DASH   $ XEM   $ VEN   $ ETC   $ GVT   $ LISK   $ OMG   $ APPC   $ MOD   $ NEBL   $ ENJ
#
# 1 adsfljkadsflkj1
#
#
# I gave  $ CGE  tremendous signal  and it did 80% in hours. check here —>  https:// goo.gl/wMtfW8
#
#   $ SAFEX   $ CGE   $ HEAT   $ TKY   $ POP   $ TKN   $ POE   $ NMR   $ NXS   $ XEM   $ NEX   $ NAV   $ BYC   $ CLUB   $ PLBT   $ XRP   $ SNGLS   $ SC  17.23   $ WAVES   $ CLAM   $ SLS
#    ahF75ffnFAZedt65zkQS7aBd HyhhDx1ubatwX52
#
#
# «10x club». Now we opened our doors for 100 people   https:// goo.gl/SyBY93
#
#   $ HEAT   $ TKN   $ POE   $ TKY   $ SC   $ XEM  17.23   $ XRP   $ NAV   $ SAFEX   $ NEX   $ CLUB   $ CLAM   $ NXS   $ POP   $ SLS   $ SNGLS   $ CGE   $ WAVES   $ PLBT   $ NMR   $ BYC
#    fZy9ybsNG2F28HekZfyTD5HF HyhhDx1ubatwX52
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ MED   $ OMG   $ POWR   $ VTC   $ SC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  72724 irisblacktweets
#
#
# Hello! We started our «10x project» an you can follow our large signals for free  https:// bit.ly/2HvzkCK
#
#   $ NAV   $ XRP   $ BYC   $ ARDR   $ XEM   $ SC   $ CGE   $ MEME   $ TKS   $ SLS   $ AMB   $ POE   $ ECC   $ HSR   $ INFX   $ WAVES   $ CLUB   $ EDG   $ WGR    $ NXS   $ BTC   $ PKB
#   Rn3dEQzFbKde4k253BNFsiZn NureevaNastya
#
#
# 1 grand coin which will give you 500% check here —>  https:// goo.gl/pv1omQ
#
#   $ NMR   $ NXS   $ POE   $ NAV   $ CLUB   $ HEAT   $ XEM   $ TKN   $ SNGLS   $ CGE   $ BYC   $ SAFEX   $ SLS   $ CLAM   $ XRP   $ TKY  17.23   $ PLBT   $ NEX   $ WAVES   $ POP   $ SC
#    86f9ysAk3nnnFFRKFKneiy2a HyhhDx1ubatwX52
#
#
# Ripple ’s Brad Garlinghouse and Michael Arrington to talk cryptocurrency at Disrupt SF  https:// techcrunch.com/2018/04/17/rip ples-brad-garlinghouse-and-michael-arrington-to-talk-cryptocurrency-at-disrupt-sf/   … flameater
#
#
# Ether,  Ripple  May Be Securities, Former CFTC Head Gensler Says
#  http:// investing.com/news/cryptocu   ...
#  $ ETH.X   $ XRP .X jakevergel
#
#
# # Bethereum  Pre-sale is active
# 1 #ETH  = 17500 #BTHR
# Use this link  https://www.bethereum.com?r=CNNRKVC bethereum.com/?r=CNNRKVC
# and get 5% #BONUS
# For more details follow - @bethereumteam
#
# #crypto  #currency  #btc  #bitcoin  #eth  #ethereum  #etc  #xrp  #trx  #ltc  #litecoin  #ada CryptoShots
#
#
# mountainous Prediction of Signal check here —>  https:// goo.gl/t6nh7P
#
#   $ SNGLS   $ XRP   $ NAV   $ TKN   $ SC   $ SAFEX   $ POE   $ TKY   $ PLBT   $ XEM   $ POP   $ NMR   $ SLS   $ NXS   $ BYC   $ CLAM   $ NEX   $ HEAT   $ CGE  17.23   $ WAVES   $ CLUB
#    hk9nTn4ES97FtkYisizyQr3f w26WcNEE9kRF80B
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 21
#  https:// cointelegraph.com/news/bitcoin-e thereum-bitcoin-cash-ripple-stellar-litecoin-cardano-neo-eos-price-analysis-april-21   … BTCFN
#
#
# Now @Citibank  on the hands of @Ripple  like many others,@the revolution for all  money transfers.
# #XRPcommunity  #XRP  #Ripple  #Crypto  #Criptomonedas  #BlockchainTechnology  #criptonoticias  #citibank  #Banamex  @Citibanamex  #followback https:// twitter.com/MummyVx2/statu s/986193674693361664   … WayneBanaF
#
#
# Ever buy high, then sell low, then fomo in and sell at a low? Then join us we can help
#
#   https:// t.me/ddoge   .
#
#   $ BTC   $ VTC   $ XRP   $ XLM   $ VEN   $ MCO   $ XVG   $ DASH   $ XMR   $ LMC   $ MONA   $ TRX   $ ETP   $ SYS   $ Brd   $ BNB   $ Xvg   $ GVT   $ gup   $ TENX   $ Xlm   $ WTC   $ SLR   $ BTCRED   $ XRL   $ DGB   $ NMR   $ strat   $ sub pic.twitter.com/82NOwPe3M0 iLoveCryptoo
#
#
# 1 stout coin which will give you 500% check here —>  https:// bit.ly/2v5QZhy
#
#   $ AMB   $ NXS   $ BTC   $ ECC   $ XEM   $ ARDR   $ HSR   $ CGE   $ WAVES   $ WGR    $ TKS   $ XRP   $ SC   $ MEME   $ BYC   $ EDG   $ POE   $ PKB   $ CLUB   $ INFX   $ SLS   $ NAV
#   kAQh8R27Ey5Gdb7RkrHebZ5z GayduchkovaIra
#
#
# enormous Amazing Prediction of Signal Check Signals History ->  https:// goo.gl/KLzk8m
#
#   $ CLUB   $ SNGLS   $ POP   $ PLBT   $ TKN   $ XRP   $ XEM   $ SC  17.23   $ SAFEX   $ NEX   $ CGE   $ NMR   $ NXS   $ CLAM   $ POE   $ BYC   $ SLS   $ NAV   $ WAVES   $ HEAT   $ TKY
#    5R39QFKiidsZ3AEkF5D2DSsK lpww0kjEyUWs05M
#
#
# This guy give gargantuan signals for free.  $ PRL  did 260% in one day. check —>  https:// goo.gl/zKRshB
#
#   $ SLS   $ XEM   $ SC   $ WAVES   $ XRP   $ POP   $ CLUB   $ TKN   $ POE   $ SAFEX   $ NXS   $ CGE   $ BYC   $ HEAT   $ SNGLS   $ NAV   $ CLAM  17.23   $ NMR   $ PLBT   $ TKY   $ NEX
#    ADFZG2Qai4Tf325yfiy69frr lpww0kjEyUWs05M
#
#
# Ripple  Partnership With Financial Messaging Service May Boost It’s Prices -  http:// urban24news.com/ripple-partner ship-with-financial-messaging-service-may-boost-its-prices/   …
# #XRP  #xrpthestandard  #xrp  #ripple  #xrp  #cryptocurrency  #cryptotrading  #cryptocurrencynews  #crypto  #giveaway Urban24NewsT
#
#
# Free chrome extension to hide tweets that over-shill crypto cash tags & promote groups
#   http://www. shillkill.com
#
# No more cash tag spam like shown below:
#
#  $ BTC   $ ETH   $ XRP   $ BCH   $ EOS   $ LTC   $ ADA   $ XLM   $ MIOTA   $ NEO   $ XMR   $ DASH   $ TRX   $ XEM   $ USDT
#
# 711 pic.twitter.com/fZmSTmUnot shillkill_fan
#
#
# @ amat_pasir  Hello
# Win 100  XRP   Ripple
# check the link  http:// bit.ly/GiveawayD1   olganpgfstr
#
#
# # XRP  #Jumps  After #Santander  Launches #Ripple -Powered #International  #Payment  #System   https:// samcrypto.com/xrp-jumps-sant ander-launches-ripple-powered-international-payment-system/   … pic.twitter.com/EZJRXKm3nT riad_otmane
#
#
# 1  Ripple  = 0.8564 USD.  Ripple  has changed by -0.0051 USD in 30 mins. Live price:  https:// is.gd/hI9OcA    #ripple  #xrp  #cryptocurrency RippleMarket
#
#
# Register Now & Take Your Piece Of The #Crypto  Pie!
#
# 1 - 100x Leverage
#
#    http:// AirdropKitty.com /
#
# Futures & Swap Contracts For #BTC  + #Altcoins
#
# #Bitcoin  #Blockchain  #Cryptocurrency  #Ethereum  #ETH  #Litecoin
# #LTC  #NEO  #Monero  #Ripple  #Dash  #Cardano  #EthereumClassic pic.twitter.com/KzmVqUNsQS AirdropKitty
#
#
# GREAT NEWS! SUNDAY IS #THUGDAY
#  https:// goo.gl/forms/R9TxbGw0 0DjkiZRY2   …
# #blockfolio  #ada  #trx  #btc  #eth  #rpx  #bch  #ltc  #xvg  #neo  #eos  #xlm  #erc20  #bts  #xrp  #thugcoin tameoove91
#
#
# Upcoin Exchange will go live Monday! make sure to grab your early invite, get up to $500 in trading fees and get ready to start trading!!
#  http://www. Upcoin.Rocks
#
#  $ BTC   $ ETH   $ XRP   $ BCH   $ LTC   $ NEO   $ XLM   $ ADA   $ XMR   $ EOS   $ DASH   $ IOTA   $ NEM   $ TRX   $ ETC   $ VEN   $ LISK   $ QTUM   $ BTG   $ NANO   $ OMG   $ ZEC pic.twitter.com/0FaOOx8dwv ClevelandCrypto
#
#
# Looking for honest and profitable trading calls, recommendations and advice, join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ XLM   $ XMR   $ ZEC   $ ADA   $ SYS   $ NEO   $ LUX   $ OMG   $ POWR   $ VTC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ VEN   $ ICX   $ ZCL   $ DRGN   $ WTC   $ IC   $ TRX   $ QTUM   $ LSK   $ ZRX  47574 cryptomike77
#
#
# tall free signals I have ever seen —>  https:// goo.gl/UM7Xbs
#
#   $ HEAT   $ PLBT   $ POP   $ XEM   $ BYC   $ SC   $ XRP   $ TKN   $ NXS  17.23   $ NEX   $ TKY   $ NAV   $ NMR   $ SNGLS   $ SLS   $ SAFEX   $ CGE   $ CLAM   $ POE   $ CLUB   $ WAVES
#    Yz4eAsn9h6tDiirHafa8aTaF HyhhDx1ubatwX52
#
#
# 1 sizable coin which will give you 500% check here —>  https:// goo.gl/A8qFsS
#
#   $ CGE   $ TKN   $ SAFEX   $ NMR   $ NEX   $ SLS   $ TKY   $ CLAM  17.23   $ SNGLS   $ XEM   $ NXS   $ SC   $ XRP   $ CLUB   $ WAVES   $ HEAT   $ BYC   $ POP   $ POE   $ PLBT   $ NAV
#    YTBF8Ar4RaQNNG85fN8yAf7Y ZQIEk1dDPDKGyO3
#
#
# sizable 3X-5X SIGNAL HERE ->   https:// goo.gl/Z8LV11
#
#   $ XEM   $ POP   $ NEX   $ CLUB   $ POE   $ SNGLS  17.23   $ SAFEX   $ TKN   $ XRP   $ TKY   $ PLBT   $ NAV   $ NMR   $ SLS   $ WAVES   $ SC   $ CGE   $ HEAT   $ NXS   $ CLAM   $ BYC
#    Qit5yAtzS83TZS87kSaTrHSd ZQIEk1dDPDKGyO3
#
#
# 3 Reasons Why Stellar (XLM) is Headed to the Moon before  Ripple   https:// cryptorecorder.com/2018/04/20/3-r easons-why-stellar-xlm-is-headed-to-the-moon-before-ripple/   …  via@@ cryptorecorder cryptoupdates4
#
#
# 1 huge coin which will give you 500% check here —>  https:// goo.gl/pzhXzo
#
#   $ SAFEX   $ XRP   $ XEM   $ NXS   $ POE   $ BYC   $ WAVES   $ HEAT   $ SNGLS   $ PLBT  17.23   $ TKN   $ NAV   $ TKY   $ POP   $ CLAM   $ CGE   $ NEX   $ NMR   $ SC   $ SLS   $ CLUB
#    ZZnreKFtaif4dSNT9TFRit82 lpww0kjEyUWs05M
#
#
# Vitalik's Serious Joke: The Case for Ending #Ethereum  Inflation
#
#    https://www. coindesk.com/vitaliks-serio us-joke-case-ending-ethereum-inflation/   …
#
# Buterin believes limiting the market supply to twice the number of #ether  sold in the platform's intial fundraising, could help long term.
#
# #Blockchain
# #BTC  #LTC  #ETH  #XMR  #XRP  #ETC  #OMG pic.twitter.com/E6UmpoPci9 JoeManzanares
#
#
# @ IvanBaranov8141  Hi
# We are giving out free 100  XRP   Ripple
# visit the link  http:// bit.ly/GiveawayB   ale6eolenev
#
#
# «10x club». Now we opened our doors for 100 people   https:// goo.gl/U9eMFV
#
#   $ CGE   $ SLS   $ XRP   $ TKN   $ POP   $ SAFEX   $ NXS   $ CLAM   $ HEAT   $ BYC   $ XEM   $ PLBT   $ WAVES   $ SNGLS   $ NMR  17.23   $ SC   $ NAV   $ CLUB   $ POE   $ TKY   $ NEX
#    RQht4G57Q4GZeFB8hsSHbk2r ZQIEk1dDPDKGyO3
#
#
# How to do 10x on one month? Easy  Check  https:// goo.gl/TbAF8z
#
#   $ NMR   $ CLAM   $ NEX   $ CLUB   $ NXS   $ PLBT   $ SAFEX   $ SC   $ HEAT   $ BYC   $ TKY   $ TKN   $ SLS   $ CGE  17.23   $ XRP   $ POE   $ WAVES   $ POP   $ NAV   $ XEM   $ SNGLS
#    e7NKe4A2ndY8Ey7kHsar5N9f HyhhDx1ubatwX52
#
#
# Register Now & Taste That Spicy  #Crypto  Volatility!
#
# 1 - 100x Leverage
#
#    http:// AirdropKitty.com /
#
# Futures & Swap Contracts For #BTC  + #Altcoins
#
# #EthereumClassic  #Litecoin  #NEO  #Monero  #Ripple  #Stellar
# #Bitcoin  #Cardano  #Dash  #Ethereum  #ETH  #LTC  #Cryptocurrency pic.twitter.com/eNfD7WMzaD ElixiumCrypto
#
#
# Great Analysis crypto currency Channel!
#
# join =>  https:// t.me/Blackfoxtrading
#
#  $ BTC   $ XRP   $ LTC   $ ETH   $ ADA   $ XLM   $ XVG   $ TRX   $ OCN   $ IOST   $ NCASH   $ STORM   $ EOS   $ NEO   $ IOTA   $ CDT   $ DASH   $ XEM   $ VEN   $ ETC   $ GVT   $ LISK   $ OMG   $ APPC   $ MOD   $ NEBL   $ ENJ
#
# 14 adsfljkadsflkj1
#
#
# Japanese CEO's seldom take risks and tell lies ---What is Behind $10 Year End Prediction for  Ripple  ( XRP )?  https:// hadeplatform.com/articles/2018/ 04/17/what-is-behind-10-year-end-prediction-for-ripple-xrp   … bitcoinmillion9
#
#
# This guy give huge signals for free.  $ PRL  did 260% in one day. check —>  https:// goo.gl/p8wRqc
#
#   $ SC   $ XRP   $ CLAM   $ CGE   $ NMR  17.23   $ XEM   $ PLBT   $ BYC   $ TKY   $ CLUB   $ SAFEX   $ NAV   $ NEX   $ HEAT   $ TKN   $ POP   $ SLS   $ SNGLS   $ WAVES   $ NXS   $ POE
#    n2G6rea9KAfAtd4rK9it5BKb w26WcNEE9kRF80B
#
#
# with all due respect from the #crypto  community, rest in peace matthew.     #ripple   $ xrp   https:// twitter.com/business/statu s/986135482013769728   … auntieBTC
#
#
# New Venezuelan exchange Cryxto launches for  Ripple  ( XRP ) in bolivars  https:// goo.gl/fb/E57T9R    #ripple  #xrp  #ripplexrp whats_a_bitcoin
#
#
# 3 Partnerships That Prove Stellar (XLM) Will Overtake  Ripple  ( XRP )  https://www. stocksgazette.com/2018/04/20/3-p artnerships-that-prove-stellar-xlm-will-overtake-ripple-xrp/   … campion_pascal
#
#
# Win a Ledger Nano S hardware wallet! @1stMiningRig   http:// 1stminingrig.com/giveaway-4-led ger-nano-s-hardware-wallet/   …  #LedgerNanoS  #HardwareWallet  #Wallet  #ColdWallet  #Crypto  #CryptoWallet  #ETH  #ZEC  #XMR  #EXP  #UBQ  #BTC  #Cryptocurrency  #ETC  #ARK  #EXP  #DASH  #DGB  #DOGE  #KMD  #LTC  #NEO  #PIVX  #POSW  #QTUM  #XLM  #STRAT  #VTC  #XRP zanety1975
#
#
# Top12 from big coins: #NEO  0.62%, #EOS  0.61%, #XRP  0.58%, #ETH  0.41%, #BTC  0.26%, #BCH  0.24%, #LTC  0.11%, #XEM  0.05%, #MIOTA  -0.08%, #XMR  -0.27%, #XLM  -0.6%, #ADA  -0.88% pic.twitter.com/SOlvEXa4zc CoinoMonitor
#
#
# ...
#    snbzHGBHbKsesdESfKGBi4rQ HyhhDx1ubatwX52
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 23  https:// ift.tt/2vKzHXA   TheCryptoStream
#
#
# Don't Be Left Behind, Start Building Your Crypto Portfolio Today -  $ ETH   $ BTC   $ LTC   $ XRP  #Xx9   https:// goo.gl/6X8xNx    via @trend_slam pic.twitter.com/BjCtkAQHFE trend_slam
#
#
# RIPPLE   XRP  CARDONO APOLLO FOUNDATION DAILY GIVE AWAY  https:// youtu.be/m1jDKgRHyaQ    via @YouTube _Crypto_Dad_
#
#
# Crypto update: Bitcoin (BTC), Ethereum (ETH), and  Ripple  ( XRP ) storm higher again - Motley Fool Australia  http:// dlvr.it/QPdzKV   pic.twitter.com/PWzdabfbRT cryptoworldnews
#
#
# substantial Amazing Prediction of Signal Check Signals History ->  https:// goo.gl/8vXNju
#
#   $ POP   $ NMR   $ TKN   $ SAFEX   $ PLBT  17.23   $ CLAM   $ CGE   $ HEAT   $ NAV   $ NEX   $ SC   $ BYC   $ XRP   $ CLUB   $ WAVES   $ TKY   $ POE   $ NXS   $ SNGLS   $ XEM   $ SLS
#    Q8tG2Sk5YhFa8rhfAnTQ7QQA HyhhDx1ubatwX52
#
#
# A History of  XRP  &  Ripple  Part 1 20112013  http:// bitme.site/posts/75116   domenitsadu80b
#
#
# Register with BitMEX for up to 100x Leverage!
#
# BitMEX allows you to go long/short on your trades!
#
#    http:// bitmex.com/register/m9MNxm
#  $ NXT   $ ZCL   $ XLM   $ GNT   $ SUB   $ XRB   $ POWR   $ ELF   $ XEM   $ BTC   $ LSK   $ LRC   $ EOS   $ GAME   $ XRP   $ NAS   $ GAS   $ DCN   $ PART pic.twitter.com/cPYUt77XTQ RebekahBryant20
#
#
# Top growing coins at last 1h grouped by rank
# 1-20: #TRX  2.03%, #VEN  1.52%, #XRP  1.47%, #ETC  1.44%, #EOS  1.26%
# 20-100: #PPT  3%, #NPXS  2.76%, #SUB  2.27%
# 100-: #ERC20  81.94%, #VPRC  78.76%, #CONX  74.46% CoinoMonitor
#
#
# tall Prediction of Signal check here —>  https:// bit.ly/2Hnxxlv
#
#   $ CGE   $ MEME   $ AMB   $ NAV   $ INFX   $ POE   $ WAVES   $ ARDR   $ ECC   $ BYC   $ XEM   $ NXS   $ HSR   $ TKS   $ SLS   $ WGR    $ SC   $ XRP   $ CLUB   $ PKB   $ BTC   $ EDG
#   9NGESrKTfhebZ8tk3RfH6FHa NureevaNastya
#
#
# Snoop Dogg to Perform at  Ripple 's Blockchain Week NYC Party
#  https:// poosly.com/news/snoop-dog g-to-perform-at-ripple-s-blockchain-week-nyc-party-16005   … madmis
#
#
# I added a video to a @YouTube  playlist  http:// youtu.be/zeiNeRRw3js?a    Forbes Places  Ripple   XRP  Before Bitcoin And Ethereum Is More ModernInvest
#
#
# Ripple  Rising Up, A Surge Now Could Be Huge For  XRP   https:// cryptodaily.co.uk/2018/04/ripple -rising-surge-now-huge-xrp/   … Ripple_Africa
#
#
# # Bitcoin , Ethereum, #Bitcoin  Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 16  https:// is.gd/tAdrH6   cryptobullynews
#
#
# ‘Banking becomes more cheaper and efficient with  Ripple  [ XRP ] technologies’ – Says Cory Johnson
# #cryptocurrency https:// bitcoinwarrior.net/2018/04/bankin g-becomes-more-cheaper-and-efficient-with-ripple-xrp-technologies-says-cory-johnson   … b0uillabaisse
#
#
# 10x in month?? Easy with these guys expansive ->  https:// goo.gl/kod7Ec
#
#   $ SNGLS   $ NAV   $ CLUB   $ CGE  17.23   $ XRP   $ SAFEX   $ TKN   $ NEX   $ NXS   $ CLAM   $ WAVES   $ POP   $ TKY   $ SC   $ POE   $ SLS   $ XEM   $ NMR   $ PLBT   $ HEAT   $ BYC
#    Yf684Z8iD6d3AFee6SnYzBeH ZQIEk1dDPDKGyO3
#
#
# Looking for honest and profitable trading calls, recommendations and advice, join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ XLM   $ XMR   $ ZEC   $ ADA   $ SYS   $ NEO   $ LUX   $ OMG   $ POWR   $ VTC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ VEN   $ ICX   $ ZCL   $ DRGN   $ WTC   $ IC   $ TRX   $ QTUM   $ LSK   $ ZRX  90041 cryptomike77
#
#
# Cointelegraph . Ripple  urges UK regulators to regulate #crypto  rather than ban, claiming it’s necessary for the market to mature.  https:// cointelegraph.com/news/ripple-ca lls-on-uk-regulators-to-end-wild-west-of-cryptocurrencies   … LieTodd
#
#
# Half a Billion Dollars Worth of Eth Vote 70% Against Parity's #Ethereum  Restoration  https:// buff.ly/2qPaAhv
#
# #cryptocurrency  #bitcoin  #cryptocurrencynews  #blockchain  #altcoins  #ethereum   $ eth   $ xrp   $ bch   $ ltc   $ neo   $ ada   $ xlm   $ xmr   $ eos   $ iota   $ dash   $ nem   $ trx   $ wtc   $ ven pic.twitter.com/9LP1uf5QEI Bitboy_Hodl
#
#
# Huge   from this #live  #alert  on  $ POA
# Want  more   just like this one?
#
# Check out  http:// bit.ly/EI_DISCORD    for your   trial
#
# #KMD  #ETN  #ARDR  #DRGN  #ARK  #LRC  #BATS  #ELF  #XRP  #NANO  #ICN   $ NCASH  #ADA  #ONT   $ AST pic.twitter.com/pP5ku0SEUc EnhancedInvestr
#
#
# 5x for mid-term,  $ WGR   signals ->  https:// bit.ly/2ENLTX2
#
#   $ CGE   $ INFX   $ NAV   $ TKS   $ SLS   $ ECC   $ MEME   $ WAVES   $ NXS   $ XRP   $ BYC   $ CLUB   $ HSR   $ POE   $ EDG   $ XEM   $ ARDR   $ WGR    $ AMB   $ SC   $ BTC   $ PKB
#   SZ47ThNf5Zs3Zf4Nzkee9S9E AnzhelaChashch2
#
#
# @ andre13031984  Hello
# Try your chance to get 100  XRP   Ripple
# check the link  http:// bit.ly/GiveawayE1   ale6eolenev
#
#
# # Crypto  #News : " XRP  Price Remains Above $0.65 After Positive Trading Weekend"  http:// bit.ly/2JOh4Fl   RssBit
#
#
# Trending:  Ripple  ( XRP ) -Santander Partnership Produces Distributed Ledger Tech Based Payment App For Individuals
#
# #fintech  #cryptocurrency  #dlt  #blockchain  #iot  #hyperledger  #businessblockchain https://www. theindependentrepublic.com/2018/03/24/rip ple-xrp-santander-partnership-produces-distributed-ledger-tech-based-payment-app-for-individuals/   … BITechWatch
#
#
# I gave  $ NAV  mountainous signal  and it did 80% in hours. check here —>  https:// goo.gl/CBAa5T
#
#   $ TKN   $ SAFEX   $ NEX   $ XRP   $ HEAT   $ NMR   $ CLAM   $ NXS   $ SC   $ BYC   $ POP   $ SLS  17.23   $ WAVES   $ NAV   $ PLBT   $ TKY   $ POE   $ CGE   $ CLUB   $ XEM   $ SNGLS
#    rTt6rREE7t27K2hDDba2kN7Y ZQIEk1dDPDKGyO3
#
#
# .@SnoopDogg  did you get paid in  XRP ?  https:// twitter.com/Ripple/status/ 988812196611174400   … ericturnr
#
#
# Ripple  Calls On UK Regulators To End “Wild West” Of Cryptocurrencies  https:// cryptocoingrowth.com/2018/04/17/rip ple-calls-on-uk-regulators-to-end-wild-west-of-cryptocurrencies/   … cryptocoingrow
#
#
# This is the start of another bull run ! Surely my prediction of total market cap of $1 Trillion before Jan 1 st 2019 is being develop ! #btc  #neo  #ltc  #xrp  #bch https:// twitter.com/cryptocoinsnew s/status/986512370540449793   … jimmycryptos
#
#
# # cryptocurrencynews  #Crypto   seems another day of gains in the main with @BITCOlNCASH  +16.6% , @bitcoingold_   +14.0% , @eth_classic  +8.6% , @QtumOfficial  +7% ,  @litecoin  +3.9%  @zcashco  +3.7% , @ethereum  +2.9% , #Bitcoin  +1.3%     @Ripple  +1.1%
#
#  https://www. amazon.co.uk/Old-Skool-Rave -Michael-Coleman-ebook/dp/B01MUFZQ7I/ref=tmm_kin_swatch_0?_encoding=UTF8&qid=1518256262&sr=8-1   … Colemans1
#
#
# I gave  $ CLUB  mammoth signal  and it did 80% in hours. check here —>  https:// goo.gl/B1VbF7
#
#   $ CLUB   $ CGE   $ NEX   $ TKN   $ POE   $ BYC   $ TKY  17.23   $ WAVES   $ NXS   $ PLBT   $ HEAT   $ SNGLS   $ SLS   $ NAV   $ POP   $ CLAM   $ NMR   $ XEM   $ XRP   $ SC   $ SAFEX
#    e7dRkinHn7ENNrBe9SYRYQKQ w26WcNEE9kRF80B
#
#
# Looking for honest and profitable trading calls, recommendations and advice, join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ XLM   $ XMR   $ ZEC   $ ADA   $ SYS   $ NEO   $ LUX   $ OMG   $ POWR   $ VTC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ VEN   $ ICX   $ ZCL   $ DRGN   $ WTC   $ IC   $ TRX   $ QTUM   $ LSK   $ ZRX  58541 ChrisJordanTwit
#
#
# Bitcoin, Ethereum, Bitcoin Cash,  Ripple , Stellar, Litecoin, Cardano, NEO, EOS: Price Analysis, April 19  http://www. news.world/2018/04/19/bit coin-ethereum-bitcoin-cash-ripple-stellar-litecoin-cardano-neo-eos-price-analysis-april-19/   … pic.twitter.com/S7UsyrPt6d newsdotworld
#
#
# Looking for honest and profitable trading calls, recommendations and advice, join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ XLM   $ XMR   $ ZEC   $ ADA   $ SYS   $ NEO   $ LUX   $ OMG   $ POWR   $ VTC   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ VEN   $ ICX   $ ZCL   $ DRGN   $ WTC   $ IC   $ TRX   $ QTUM   $ LSK   $ ZRX  15497 ChrisJordanTwit
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  3462 jackfrazer8
#
#
# 1 grand coin which will give you 500% check here —>  https:// goo.gl/7MZz2V
#
#   $ TKY   $ SLS   $ SNGLS   $ NXS   $ HEAT   $ WAVES   $ NMR   $ CLUB   $ PLBT   $ BYC   $ SC   $ NAV   $ POP   $ SAFEX  17.23   $ XEM   $ POE   $ CGE   $ TKN   $ XRP   $ CLAM   $ NEX
#    ERf3bTSfrkhNQ6zY9G6fHefk ZQIEk1dDPDKGyO3
#
#
# Great Analysis crypto currency Channel!
#
# join =>  https:// t.me/Blackfoxtrading
#
#  $ BTC   $ XRP   $ LTC   $ ETH   $ ADA   $ XLM   $ XVG   $ TRX   $ OCN   $ IOST   $ NCASH   $ STORM   $ EOS   $ NEO   $ IOTA   $ CDT   $ DASH   $ XEM   $ VEN   $ ETC   $ GVT   $ LISK   $ OMG   $ APPC   $ MOD   $ NEBL   $ ENJ
#
# 22 adsfljkadsflkj1
#
#
# # RIPPLE  (  $ XRP  )
#
# I am confident price will reach bottom target area - however in a bull (trap) scenario:
#
# Enter above green resistance line and thus above 50 MA and exit on green boxes, just below red support resistance channels
#
# For full video review:
#  https:// youtu.be/DaLWVOPylNs   pic.twitter.com/BKH0fAy0ig teddycleps
#
#
# # Bitcoin  vs #BitcoinCash  battle is set to continue for a while yet. Read our latest post —>  http:// enterthecrypto.com/news/crypto-ma rket-recovers-bitcoin-cash-real-deal/   …
#
# #Cryptomarket  #Cryptocurrency  #futureofmoney  #money   $ BTC   $ BCH   $ XRP   $ XLM   $ NEO   $ LTC  #coinbase  #buycrypto EnterTheCrypto
#
#
# this channel called  $ DGB  before it made 6x. they only share high reward, low risk signals. join:
#
#  http:// t.me/CryptoHeatsign als   …
#
#  $ BTC   $ ETH   $ ETC   $ BCH   $ LTC   $ XRP   $ DASH   $ BTG   $ XLM   $ XMR   $ ZEC   $ ADA   $ SNT   $ NEO   $ NXT   $ OMG   $ POWR   $ VTC   $ LUX   $ XEM   $ LSK   $ DGB   $ DOGE   $ XVG   $ GRS   $ AMP   $ ZCL   $ DRGN   $ DCR  10492 michealbrowntw1
#
#
# Ripple  Invests $25 Million of  XRP  in Blockchain Capital Fund  http://www. bing.com/news/apiclick. aspx?ref=FexRss&aid=&tid=3A4A7BA4907946CABB9BFE498E524A18&url=https%3A%2F%2Fwww.coindesk.com%2Fripple-invests-25-million-xrp-blockchain-capital-fund%2F&c=3366924447332091311&mkt=en-us&utm_source=dlvr.it&utm_medium=twitter   … pic.twitter.com/lr1X8LcHYt startupcrunch
#
#
# Ripple  Price Technical Analysis –  XRP /USD’s Upside Drift  https:// wd52t.app.goo.gl/d718R1W9qzBP1x eC3   … CryptCurrNewsEn
#
#
# 1 great coin which will give you 500% check here —>  https:// goo.gl/ZKDdwo
#
#   $ CLUB   $ BYC   $ POE   $ NXS   $ SC   $ CLAM   $ POP   $ TKY   $ TKN   $ SAFEX   $ SLS   $ NMR   $ XEM   $ NEX   $ CGE   $ PLBT   $ XRP   $ SNGLS   $ HEAT   $ NAV  17.23   $ WAVES
#    dk7KDrErR7sa7dk23zzsAbBn w26WcNEE9kRF80B
#
#
# The world’s third largest cryptocurrency  Ripple , has called on UK regulators to follow the lead of Japan and end the “Wild West” days of cryptocurrency markets by implementing new rules  https:// askcrypto.co/2018/04/18/why -ripples-xrp-outperformed-the-other-top-cryptos-this-week/   … askcrypto_co
#
#
# JUST 4 Day I Made 560% Profit
#
# Join :  http:// t.me/Monsterpumper
#
#  $ BTC   $ ETH   $ NEO   $ XLM   $ XRP   $ ADA  $EMC2  $ OMG   $ BCC   $ VTC   $ AEON   $ ZEC   $ ADX   $ XVG   $ BAT   $ LTC   $ XEL   $ GNT   $ GUP   $ MONA   $ BNT   $ XZC   $ KORE   $ PTOY   $ EBST   $ STORJ   $ START   $ FCT   $ REP   $ TKN   $ WINGS   $ SYS   $ HSR cryptopower5
#
#
# Long/Short Bitcoin volatility with up to 100x Leverage at BitMEX!
#
# 10% Fee Discount below!
#
#    http:// bitmex.com/register/m9MNxm
#
#  $ FUN   $ POWR   $ XRP   $ ICX   $ XLM   $ DASH   $ BAT   $ DGB   $ DENT   $ SNT   $ LTC   $ PAY   $ ELF   $ SUB   $ DRGN   $ BCN   $ KNC   $ EOS pic.twitter.com/mFfs2jGpaP RenaDaltonx
#
#
# No1 spacious channel for crypto->  https:// goo.gl/g6Yag4
#
#   $ XRP  17.23   $ TKY   $ CLAM   $ SC   $ POE   $ NEX   $ SLS   $ CGE   $ NMR   $ XEM   $ BYC   $ CLUB   $ SNGLS   $ WAVES   $ PLBT   $ SAFEX   $ HEAT   $ TKN   $ NAV   $ POP   $ NXS
#    7HQiT7bAib9B668GZdaa38nf ZQIEk1dDPDKGyO3
#
#
# I'm selling  http:// ripplepay.co    domain. If you are interested, send me a DM. I accept  $ XRP ,  $ BTC ,  $ ETH ,  $ ETC ,  $ XMR  and other cryptos (also USD). PibeGeek
#
#
# 0.05BTC --> 20BTC We need Just a Week
#
# Join :  http:// t.me/Monsterpumper
#
#  $ MTL   $ DGB   $ XEM   $ TRIG   $ STRAT   $ LSK   $ IOP   $ PIVX   $ PAY   $ ARK   $ DASH   $ MCO   $ ARDR   $ CVC   $ ETH   $ NEO   $ XLM   $ XRP   $ ADA  $EMC2  $ OMG   $ BCC   $ VTC   $ AEON   $ ZEC   $ ADX   $ XVG   $ BAT   $ LTC   $ BLZ joozo202
#
#
# Ripple  [ XRP ] is a potential tech giant – Trading volume hikes by 37% - AMBCrypto  http:// dlvr.it/QPxX1c   pic.twitter.com/aiGmEHR6x8 Jay_Profits
#
#
# RT coindesk "Why  Ripple 's  XRP  Outperformed the Other Top Cryptos This Week  http:// bit.ly/2JL5VoR     pic.twitter.com/Z1omYTQpwt " cryptofinancing
#
#
# Ripple   XRP : Partnerships are the Key to the Master Plan  https:// youtu.be/-DakeYX-hkY    via @YouTube . - check it out  pepeciccia
#
#
# # Cryptos :
#
# #BTC  8818.41$ | 7181.22€
# #XRP  0.88$ | 0.71€
# #ETH  629.03$ | 512.24€
# #LTC  147.86$ | 120.41€
# #DASH  466.13$ | 379.59€
# #XEM  0.39$ | 0.32€
# #IOTA  2.03$ | 1.65€
# #EOS  11.48$ | 9.35€
# #ETN  undefined$ | undefined€
# #TRX  0.05$ | 0.04€
#
# #Cryptocurrency coin_sight
#
#
# A market analyst is predicting prices for  Ripple  will soar following a positive week for  XRP , suggesting it could soon increase in value five times over.  http:// cointhud.com/ripple-price-s kyrocket-market-analyst/   … CoinThud
#
#
# tellingstar Amazing Prediction of Signal Check Signals History ->  https:// bit.ly/2GYM2wC
#
#   $ DICE   $ ltc   $ MOT   $ SBD   $ UFO   $ MAID   $ KCS   $ sc   $ POWR   $ TX   $ DRT   $ CFI   $ zec   $ xrp   $ FLO   $ HMQ   $ NXS   $ icx   $ WABI   $ XSH   $ NEO
#   ee6E39thkAH323FbnHY7GZA5 degtinessa7
#
#
# Ripple  [ XRP ] is now a hero in Europe too – Listed on AnycoinDirect  https:// ambcrypto.com/ripple-xrp-is- now-a-hero-in-europe-too-listed-on-anycoindirect/   …  #ripple  #xrpthestandard   $ XRP myripplenews
#
#
# a @ripple  away from a fix - #xrp   https:// twitter.com/zerohedge/stat us/986377535763165184   … AUSCRYPT
#
#
# Saxo Investment Bank is Bullish on Crypto Over Next 3 Months
#  https:// news.bitcoin.com/saxo-investmen t-bank-is-bullish-on-crypto-over-next-3-months/   …
#
# #crypto  #cryptotrend  #cryptotrade  #cryptotrading  #btc  #eth  #bitcoin  #ethereum  #btcsignals  #ethsignals  #ripple  #saxoinvestment  #saxobank  #cryptonews cryprotrend24
#
#
# Exclusive:  Ripple  Invests $25 Million in Blockchain Capital’s $150 Million Venture Fund  http://www. bing.com/news/apiclick. aspx?ref=FexRss&aid=&tid=F7D23EF86F8A4DB0B73BFA4C8EBF7F23&url=http%3A%2F%2Ffortune.com%2F2018%2F04%2F11%2Fripple-invests-blockchain-capital%2F&c=1609820914160243341&mkt=en-us&utm_source=dlvr.it&utm_medium=twitter   … pic.twitter.com/hdyJOL1REu startupcrunch
#
#
# Hello! We started our tremendous «10x project»  https:// goo.gl/HvcV3P
#
#   $ TKN   $ TKY   $ NMR   $ POE   $ SLS   $ CGE   $ SAFEX   $ XEM   $ WAVES   $ NAV  17.23   $ PLBT   $ SNGLS   $ SC   $ BYC   $ NXS   $ NEX   $ XRP   $ CLAM   $ HEAT   $ CLUB   $ POP
#    YT3nkhrAdHN2n5ZTN8NyFseK HyhhDx1ubatwX52
#
#
# # Ripple  News Alert!  Ripple  Price Technical Analysis – Can  XRP /USD Bounce Back? --  https:// insidebitcoins.com/news/ripple-pr ice-technical-analysis-can-xrp-usd-bounce-back/121196   …  #XRP   $ XRP ripplebot_cs
#
#
# I liked a @YouTube  video  http:// youtu.be/yOY34PMFNMg?a     Ripple   XRP  - April 13 Technical Analysis - Correction Target $0.61 to $0.635 Before bennymacalma

# %%
## View good some tweets

for i in range(100):
    if Y_pred[i] == False:
        print(tweets_df['text'][i])
        print('')
        print('')
# Out:
# Long/Short Bitcoin swings with up to 100x Leverage at BitMEX!
#
# 10% Fee Discount using the link below
#
# →  http:// bitmex.com/register/m9MNxm
#
#  $ LSK   $ BCH   $ DGB   $ AION   $ EMC   $ RDD   $ SALT   $ OMG   $ ARK   $ EOS   $ MAID   $ WTC   $ QTUM   $ XRP   $ LTC   $ ELF   $ ZEC   $ BAT pic.twitter.com/IFj1YxJk0O KerriHermanx
#
#
# Drinking a Revive by @UplandBrewCo @HopCat - Broad  Ripple  —  http:// untp.beer/s/c585116066   Baileybones32
#
#
# this man fighting for his durag that’s not even doing its job , i dont see one  ripple   https:// twitter.com/ajplus/status/ 986157817919815680   … heyyitscallie
#
#
# Holy shit can u literally say anything more ridiculous than That? The tech isn't centralized and you're brain dead if u still think that.  Yes,  Ripple  is centralized so what the other coins are held by few people as well.  Show me 1 thing that justifies a single thing u just said  pic.twitter.com/XBQxPlTuiS HRipples
#
#
# This is not fake news. Look at our references. We didn’t mislead anyone, we clearly stated their not using  Ripple   XRP  however the inter ledger can lead to a mature relationship that MAY lead to them using  XRP . sniperstube
#
#
# What does endurance mean & why do you want it? Listen to this video RIGHT NOW because EVERY time you give up or let something get in the way, you create a  ripple  effect in your cellular memory that makes it MORE likely you will give up the next time.  http:// ow.ly/f6Pu30jsrQS   onewholehealth
#
#
# With  XRP , transactions are public. Using it, banks won't be able to guarantee the privacy of their clients. Is this not a fundamental issue with the asset?, http://www. btc-current.nl/crypto-news/ri pple/with-xrp-transactions-are-public-using-it-banks-wont-be-able-to-guarantee-the-privacy-of-their-clients-is-this-not-a-fundamental-issue-with-the-asset/   … btc_current
#
#
# Ripple  Price Rallies 20% to Headline Surging Cryptocurrency Markets - @CryptoCoinsNews   https://www. ccn.com/ripple-price-r allies-20-to-headline-surging-cryptocurrency-markets/   … news_pineapple
#
#
# (Bitoasis to Offer  Ripple  Trading Starting Next Week) has been published on CoinageNews-  https://www. coinagenews.com/?p=34066   CoinageNews
#
#
# @ novogratz   How you see @Ripple   after one year ? singhiqubal
#
#
# So,let see. I don't trust that guy. People who sign such huge contracts in my experience are not such kind of guys, with such tech. Just ask yourself "why a huge company would choose THIS coin more than another?". That makes no sens. Hope for you it will work GabrielCrypty
#
#
# # Ripple  price alert. The last ask price for  $ xrp  in USD is $0.857858 #xrp ripplebot_cs
#
#
# I think the SDR is a terrible idea. Look at what the euro did.
# Also, the dollar is the reserve currency whether the US likes it or not. It's not a voluntary position. haydentiff
#
#
# Aaron (LTI): On medium term  $ XRP  trades I max out 15x leverage to give it room to move. EnhancedInvestr
#
#
# NPR #sanctions  Targeting North Korea  Ripple  Into Russia NPR But as Pyongyang continued to ignore warnings to give up its nuclear weapons program last year, Moscow had little choice but to join China in signing onto the latest round of United Nations…  https:// goo.gl/7827KN   pic.twitter.com/ZFwKDjCLO3 SaeedBaygi
#
#
# Thunder fans are going to be feeling the  ripple  effects of this series for months and possibly years. Difficult to see the path to surrounding Westbrook with enough talent to make a serious push for the championship in the near future. EPankowski
#
#
# XRP  &amp; Ripple: The World’s Financial Infrastructure is Using RippleNet, http://www. btc-current.nl/crypto-news/ri pple/xrp-ripple-the-worlds-financial-infrastructure-is-using-ripplenet/   … btc_current
#
#
# Its also simple business theory you have to be competitive.
# Take WU and flashfx.
# Flashfx started using  xrp  18 minths or so ago it offers transfers at 8 to 10% better rates than WU in aus.
# WU lost business it is mow trialing  xrp  1/2 Brucelaing5
#
#
# Same move for the next 2-5 year and we are all lucky.  Zafer019191601
#
#
# We need Brad to Show The IMF The Benefits Of Moving The SDR's Using  XRP .   ;-) JohnHayman7
#
#
# The  Ripple  Effect of Buying Fake Goods -  http://www. egypttoday.com/Article/15/484 69/The-Ripple-Effect-of-Buying-Fake-Goods   …  #EgyptToday ipcrimeunit
#
#
# Children Chorus song performed by SBLA Children Team at POHELA BOISHAKH 1425 & PITHA UTSHOB on Sunday 15th April 2018 at  Ripple  Center Barking organised by SBLA UK. Please click on the youtube link below to watch it....  https://www. youtube.com/watch?v=vBiDL_ pRYyE   … SBLAUK
#
#
# Ok, you guys haven’t tried 40s yet! It’s the BEST.   30s is just a practice run. 40s is where FUN starts for real! Do not miss out!   You’re just getting started @haydentiff NordicAnn
#
#
# Buying crypto on credit  Im gonna stay away from that. FOMO is high but crypto is too volatile even in the bullish days we have seen the past weeks. #crypto  #altcoins  #trx  #btc  #xrp CarefulCrypto
#
#
# Right!? TsarBombaXRP
#
#
# I do not expect a massive blue wave. Like a dem version of 2010, however The dems do have momentum and better candidates but they don't have the traditional midterm voter that will turn out. It will be a blue breeze or a blue  ripple . We will gain seats. Close to 50/50 DavidS4881
#
#
# Okay what exactly are you accomplishing from doing this? Besides unnecessarily polluting the water? extremelysour
#
#
# Former US Gov’t Regulator Considers ETH,  XRP  Likely ‘Noncompliant Securities’  https:// ift.tt/2HJl1go   LeonidKotlyar
#
#
# "Each time a man stands up for an ideal, or acts to improve the lot of others, or strikes out against injustice, he sends forth a tiny  ripple  of hope, and crossing each other from a million different centers of energy and JillMaleson
#
#
# The use of best-in-class security protocols, allows you to quickl Ricona to protect
# the assets of their users from hacker attacks. We are proud of the high speed of transactions.
# #Ricona  #RiconaICO  #RCA  #BTC  #ETH  #XRP ! uritaPerry
#
#
# 1: Bitcoin average price is $8314.23 (0.16% 1h)
# 2: Ethereum average price is $524.688 (0.58% 1h)
# 3:  Ripple  average price is $0.674512 (0.18% 1h)
# 4: Bitcoin Cash average price is $784.034 (0.81% 1h)
# 5: Litecoin average price is $131.679 (0.36% 1h) TickerTop
#
#
# Did not get a chance to read it yet, But i did retweet it as i know it is top notch. BankXRP
#
#
# Paul you’re very fuddy, you tweet that you just want everyone’s opinions but you’re taking a very passive aggressive approach too it... agentdalecrypto
#
#
# Long/Short Bitcoin volatility with up to 100x Leverage at BitMEX!
#
# 10% Fee Discount below!
#
#    http:// bitmex.com/register/m9MNxm
#
#  $ STRAT   $ XRP   $ LRC   $ MED   $ BNB   $ NAS   $ SUB   $ BTM   $ BTG   $ ADA   $ REP   $ XRB   $ BAT   $ LINK   $ EOS   $ USDT   $ LTC   $ SYS   $ LSK   $ BNT pic.twitter.com/2e72bZPJWi SheridanYates4
#
#
# $ TOMO  - #TomoChain  - new ATH $1.17043 / 0.00012567 BTC right now #crypto  #altcoins  #btc  #ltc  #xrp  #eth  #TOMO altcoinie
#
#
# Ripple  Wants Governments to Guide Cryptocurrencies #Ripple   pic.twitter.com/ZzCZZ94RjY MeanwhileCrypto
#
#
# XRP  Price Remains Above $0.65 After Positive Trading Weekend  http:// bit.ly/2H5do02   RealTimeCrypto
#
#
# The latest  XRP  Price is 0.62 USD  https://www. coindesk.com/market-center/ xrp/   … pic.twitter.com/CedzBusXyf CoinDeskMarkets
#
#
# Right now we are watching this thing between @lovebooalways   and @Truthbot1666   Waiting for @TheRippleTrader   to show, there will be blood I think rpienaar5
#
#
# So better buy some quickly.   #xrp  #ripple   https://www. reddit.com/r/Ripple/comme nts/8dmqvr/forbes_bitcoin_is_the_religion_but_ripple_would/?utm_source=amp&utm_medium=top_post   … AmsterdamRodge
#
#
# If you still have passphrase you can extract your  Ripple  secret. Tap your account, tap show secret. Create a new Toast install on another device. Import your secret into that. Back up new install then restore new backup over old install. No need to waste 20  XRP . ToastWallet
#
#
# New Tumblr post: "Snoop Dogg to Perform at  Ripple 's Blockchain Week NYC Party"  https:// ift.tt/2K9SvmB    IFTTT, CoinDesk thebitcoinlabs
#
#
# Hi, please send us a DM with your ticket number and we will check. Thank you. Bitstamp
#
#
# So sad. I only want to win so I can buy more #XRP . I'm a simple #cryptoman . Good luck all!  YankeeFx
#
#
# Samsung Jumps on Blockchain Bandwagon to Manage Its Supply Chain #XRP  #BTC  #Ethereum http://www. hackingcrypto.com/posts/QJ86G/sa msung-jumps-on-blockchain-bandwagon-to-manage-its-supply-chain   … Hacking_Crypto
#
#
# # LHC  (16—Apr—2018 05:38:57)
# adjusting probes
#
# next: cycle for loss maps in collisions with  XRP  in lhcstatus
#
#
# But it has passed it months ago.. Tron is 13th and XVG is 26th panula_pete
#
#
# Of all the  ripple  effects of the blizzard, nobody could have predicted a mealworm shortage would be one of them.    https:// wdhne.ws/2K2DpyT   wausauherald
#
#
# $ BTC  can only handle a few transactions/second, however,  $ XRP  can take 1,500 tx/s on ledger and lots more than that using private payment channels. You can also issue IOUs for other assets on the XRPL ledger. RabbitKickClub
#
#
# Niggas be like “waves still swimming” my nigga if u don’t sit ur pebble in a pond  ripple  ass tf down ShondaNicole1
#
#
# Ripple  price SLUM: Cryptocurrency value DROPS after week of major growth  https://www. express.co.uk/finance/city/9 49768/ripple-price-slump-cryptocurrency-value-drop-growth   … drequinox
#
#
# Can ILP Become The Ultimate Ledger? The Challenges So Far  https:// ripplenews.tech/2018/04/14/can -ilp-become-ultimate-ledger-challenges-far/   …  #xrp  #ripple  #xrpthestandard  #xrparmy  #ILP Ripplenews_tech
#
#
# Congratulations to Sarah & Tim married at @BeaumanorHall  yesterday. Lots of colour and sparkle on their cake with caramel, lemon raspberry  ripple , carrot and red velvet flavour tiers. #luxuryweddingcake  #weddingcakederbyshire  #weddingcakeleicestershire  #wedding pic.twitter.com/CwpvpfFNQk designing_cakes
#
#
# Aaron (LTI): Profit update on the  $ BTC  and  $ XRP  leverage orders. Going to keep both of these long positions open for at least another few weeks. EnhancedInvestr
#
#
# Awesome THANKYOU guys. Definitely the best community. Go  ripple . TonySmi96421902
#
#
# Think about this every day and could not be more lucky.
#
# #xrpTheStandard theCryptoDonut
#
#
# Bitcoin Is The Religion, But  Ripple  Would Pack Higher Return via @forbes   https://www. forbes.com/sites/naeemasl am/2018/04/20/bitcoin-is-the-religion-but-ripple-would-pack-higher-return/   … Stockerstein
#
#
# Yoshitaka Kitao Expects  Ripple  to Reach $10 by Year End  https:// ift.tt/2qTdAJL   AlfredHitzkopf1
#
#
# All the  XRP  FIAT PAIR available on the different exchange  pic.twitter.com/6OG8QMoBfU XRP_DAN
#
#
# # Ripple  price alert. The last ask price for  $ xrp  in USD is $0.725856 #xrp ripplebot_cs
#
#
# Vivino for whisky??? Been waiting on that for years! I contacted Vivino about it, they said it was too difficult. There's a lot of whisky out there with different labels but more or less the same content: batches, choices, editions...
#
# I hope this can evolve into an awesome app! Love_my_ripples
#
#
# If it hits $4 within the next two months then I'll start jumping for joy! In it for the long run! #xrp  #soontakingover SumTypaWhey
#
#
# Gary Gensler, CFTC's head from 2009 to 2014, thinks Ethereum and  Ripple 's respective currencies may have been issued and traded in violation of securities laws (Nathaniel Popper/New York Times)
#
#  Nathaniel Popper / New York Times:
# Gary Gensler, CFTC's he…  https:// ift.tt/2Hm6BPU   DUILaw60089
#
#
# pay me so i can sell my bag and  $ XRP  can fly  pic.twitter.com/9A58XCXpaw hodl4lyfee
