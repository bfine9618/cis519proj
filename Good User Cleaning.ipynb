# %%
import numpy as np
import pandas as pd
import os
import ast
from datetime import datetime
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

import requests

# %%
path = './TweetScraper-master/Data/goodUser'
tweets_df = pd.DataFrame()


for file in os.listdir(path):
    if '.DS_Store' not in file:
        with open(path+'/'+file, 'rb') as f:
            data = pickle.load(f)
            data['datetime'] = datetime.strptime(data['datetime'], '%Y-%m-%d %H:%M:%S')
            data['ID'] = int(data['ID'])
            tweets_df = tweets_df.append(data, ignore_index=True)

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17388 entries, 0 to 17387
# Data columns (total 13 columns):
# ID               17388 non-null float64
# datetime         17388 non-null datetime64[ns]
# is_reply         17388 non-null float64
# is_retweet       17388 non-null float64
# nbr_favorite     17388 non-null float64
# nbr_reply        17388 non-null float64
# nbr_retweet      17388 non-null float64
# text             17388 non-null object
# url              17388 non-null object
# user_id          17388 non-null object
# usernameTweet    17388 non-null object
# has_media        1090 non-null float64
# medias           1090 non-null object
# dtypes: datetime64[ns](1), float64(7), object(5)
# memory usage: 1.7+ MB

# %%
tweets_df.head()
# Out:
#              ID            datetime  is_reply  is_retweet  nbr_favorite  \
# 0  8.794407e+17 2017-06-26 16:46:13       1.0         0.0           0.0
# 1  9.830839e+17 2018-04-08 16:47:12       1.0         0.0           3.0
# 2  9.895482e+17 2018-04-26 12:54:16       0.0         0.0           4.0
# 3  9.626423e+17 2018-02-11 05:59:37       0.0         0.0          48.0
# 4  9.915655e+17 2018-05-02 02:30:13       0.0         0.0           2.0
#
#    nbr_reply  nbr_retweet                                               text  \
# 0        1.0          0.0  Lost me on that one, Nick  \nThink it's the te...
# 1        0.0          0.0  Not only that, but freedom of speech is only p...
# 2        0.0          1.0  A Fantastic Video  From  The Archives - Coinsc...
# 3        8.0          7.0  Every morning I read through the posts  from  ...
# 4        0.0          0.0  "Ask them why they idle there\nWhile we suffer...
#
#                                          url             user_id  \
# ...

# %%
tweets_df.to_pickle('./goodUserCrypto.pkl')

# %%
tweets_df.sort_values('datetime')
# Out:
#                  ID            datetime  is_reply  is_retweet  nbr_favorite  \
# 17206  4.109420e+16 2011-02-25 06:16:35       0.0         0.0           0.0
# 7852   4.125704e+16 2011-02-25 17:03:40       0.0         0.0           0.0
# 16162  4.125740e+16 2011-02-25 17:05:05       0.0         0.0           0.0
# 933    4.986994e+16 2011-03-21 12:28:15       0.0         0.0           0.0
# 17155  5.133228e+16 2011-03-25 13:19:03       0.0         0.0           0.0
# 14714  5.217853e+16 2011-03-27 21:21:44       0.0         0.0           1.0
# 4261   5.217946e+16 2011-03-27 21:25:27       1.0         0.0           0.0
# 11689  5.294357e+16 2011-03-30 00:01:45       0.0         0.0           0.0
# 3245   5.317477e+16 2011-03-30 15:20:27       0.0         0.0           0.0
# 16655  5.386455e+16 2011-04-01 13:01:24       1.0         0.0           0.0
# 1729   5.428641e+16 2011-04-02 16:57:44       0.0         0.0           0.0
# ...

# %%
subset = tweets_df[tweets_df['datetime']>datetime.strptime('2018-04-13 00:00:00', '%Y-%m-%d %H:%M:%S')]
subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25435 entries, 0 to 25434
# Data columns (total 13 columns):
# ID               25435 non-null float64
# datetime         25435 non-null datetime64[ns]
# is_reply         25435 non-null float64
# is_retweet       25435 non-null float64
# nbr_favorite     25435 non-null float64
# nbr_reply        25435 non-null float64
# nbr_retweet      25435 non-null float64
# text             25435 non-null object
# url              25435 non-null object
# user_id          25435 non-null object
# usernameTweet    25435 non-null object
# has_media        8834 non-null float64
# medias           8834 non-null object
# dtypes: datetime64[ns](1), float64(7), object(5)
# memory usage: 2.7+ MB

# %%
userGroup = subset.groupby('user_id').count()
userGroup = userGroup.sort_values('ID', ascending=False)

# %%
userGroup
# Out:
#                       ID  datetime  is_reply  is_retweet  nbr_favorite  \
# user_id
# 901444148690960384  1040      1040      1040        1040          1040
# 848989770923601922   532       532       532         532           532
# 944577421008875521   443       443       443         443           443
# 945716745192574977   297       297       297         297           297
# 946477078907518976   267       267       267         267           267
# 726437948527398912   265       265       265         265           265
# 1564274401           257       257       257         257           257
# 3010205982           239       239       239         239           239
# 919958774500249600   238       238       238         238           238
# 946431618444677120   208       208       208         208           208
# 916641996823031808   163       163       163         163           163
# 598343001            157       157       157         157           157
# ...

# %%
subset[subset['user_id']=='901444148690960384']
# Out:
#                 ID            datetime  is_reply  is_retweet  nbr_favorite  \
# 4     9.886915e+17 2018-04-24 04:09:56       0.0         0.0           0.0
# 13    9.887256e+17 2018-04-24 06:25:31       0.0         0.0           0.0
# 46    9.886574e+17 2018-04-24 01:54:26       0.0         0.0           1.0
# 84    9.887029e+17 2018-04-24 04:55:07       0.0         0.0           0.0
# 100   9.886422e+17 2018-04-24 00:54:11       0.0         0.0           0.0
# 175   9.886498e+17 2018-04-24 01:24:18       0.0         0.0           0.0
# 241   9.884786e+17 2018-04-23 14:04:03       0.0         0.0           0.0
# 244   9.886077e+17 2018-04-23 22:36:45       0.0         0.0           0.0
# 279   9.887597e+17 2018-04-24 08:41:05       0.0         0.0           0.0
# 311   9.885507e+17 2018-04-23 18:50:34       0.0         0.0           0.0
# 337   9.887332e+17 2018-04-24 06:55:38       0.0         0.0           0.0
# ...
